# %%
import ipywidgets as widgets
from IPython.display import display
import suppliers.execute_scenarios as executor
from src.suppliers import Supplier

s = Supplier(supplier_prefix = 'ksp', lang='en')

s.driver.get_url('https://www.ksp.co.il')
# Out:
# True

# %%
executor.execute_list_of_scenarios(s)
# Out:
# 2023-03-11 18:49:17.376 | ERROR    | web_driver:_get_webelments_from_page:633 -  Не найден элемент по локатору
#                 {'attribute': 'href', 'by': 'xpath', 'selector': "//a[contains(@class,'MuiTypography') and contains(@href , 'web/item')]", 'action': None}
#
# 2023-03-11 18:49:17.378 | ERROR    | suppliers.execute_scenarios:get_list_products_in_category:164 -  Ты кто? <class 'bool'>
# 2023-03-11 18:49:39.988 | ERROR    | suppliers:save_and_send_via_ftp:228 -  Файл 2787-210989.png не записался 'Supplier' object has no attribute 'send_via_ftp'
# 2023-03-11 18:49:39.989 | ERROR    | suppliers:save_and_send_via_ftp:241 -  Файл 2787-210989.png не записался 'AttributeError' object has no attribute 'errno'
# ...

# %%
#s.d.get_url('https://ksp.co.il')

# %%
scenarios = ["ksp_categories_motherboards_msi.json",
    "ksp_categories_monitors_lg.json",
    "ksp_categories_monitors_lenovo.json"]
#executor.run_scenario_file(s, 'ksp_categories_monitors_lenovo.json')
#executor.execute_list_of_scenarios(s,scenarios)
