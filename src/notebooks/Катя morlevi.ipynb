# %%
import ipywidgets as widgets
from IPython.display import display
import suppliers.execute_scenarios as executor
from src.suppliers import Supplier

s = Supplier(supplier_prefix = 'morlevi', lang='en')
s.run()
# Out:
# 2023-03-11 18:50:59.444 | DEBUG    | suppliers.morlevi:_login:64 -  Собссно, логин Морлеви
# 2023-03-11 18:51:09.292 | DEBUG    | suppliers.morlevi:_login:79 - Mor logged in
# 2023-03-11 18:51:16.111 | ERROR    | web_driver:_get_webelments_from_page:633 -  Не найден элемент по локатору
#                 {'attribute': None, 'by': 'xpath', 'selector': "//ul[@class='pagination']//a[@class='page-link']", 'action': 'click()'}
#
# 2023-03-11 18:51:16.112 | ERROR    | web_driver:_click:668 -  Не на что кликать. Локатор: {'attribute': None, 'by': 'xpath', 'selector': "//ul[@class='pagination']//a[@class='page-link']", 'action': 'click()'}
# 2023-03-11 18:51:17.122 | ERROR    | suppliers.product:_open_templates_keys:176 -  Проверь узел сценария {'storage': 'COMPUTER STORAGE'}
# 2023-03-11 18:51:23.277 | ERROR    | web_driver:_get_webelments_from_page:633 -  Не найден элемент по локатору
# ...

# %%
#executor.run_scenario_file(s,'morlevi_categories_headsets.json')
#executor.execute_list_of_scenarios(s)

# %%
#d.close()
