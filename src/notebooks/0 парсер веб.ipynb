# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Парсер Веб.](#toc1_)
# - [<red>Важно! </red>](#toc2_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # <a id='toc1_'></a>[Парсер Веб.](#toc0_)
# **Цель проекта**: Сбор и анализ информации из неструктурированных источников с целью дальнейшего анализа и выдачи данных в формате стандартизирового каталога.
#
# **Пример задачи**: Для примера я возьму сценарий, который соберет мне ассортимент материнских плат для сборки
# копьютерных систем для таких задач, как игры, программирование и искусстенный интелект. Намерено я взял этот пример в силу того, что имею представление о сути вопроса.
#
#
# **Начнем**
# Формализация:
# -   Я собираю каталог товаров от разных поставщиков и отдаю структурированную таблицу
#
#
#
# Скелет системы - 3 больших класса, три кита на которых построен сбор и струкурирование информации:
# - Сущность (class ***Product***)
# - Поставщик (class ***Supplier***)
# - Вебдрайвер. (class ***Driver***)
#
# Начну с вебдрайвера: его задача - связь с браузером. По умолчанию я выбрал Mozilla, т.к. ее довольно часто используют для подобного решений. Но вполне можно использовать и другие, правда, я их еще не проверял :).
#
# Приступим.

# %% [markdown]
# # <a id='toc2_'></a>[<red>Виртуальная среда </red>](#toc0_)
#  Включить venv
#  <h3>Команды для PowerShell </h3>

# %% [markdown]
# <code><pre>
# py -m venv venv
# venv/Scripts/Activate
# pip install -r requierements.txt
# </pre></code>

# %%
# !python3 -m venv venv
# !venv/Scripts/Activate.ps1
# !pip install -r requierements.txt

# %%
from .. import main as main
from main import start_script as run
run('aliexpress')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from .. import main as main
#       2 from main import start_script as run
#       3 run('aliexpress')
#
# ImportError: attempted relative import with no known parent package

# %%
import gs
