# %%
import ipywidgets as widgets
from IPython.display import display
import suppliers.execute_scenarios as executor
from src.suppliers import Supplier

s = Supplier(supplier_prefix = 'ebay', lang='en')

s.driver.get_url('https://www.ebay.com')
# Out:
# True

# %%
s.login()

# %%
#s.run()

# %%
executor.execute_list_of_scenarios(s)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22008\2632448135.py in <module>
# ----> 1 executor.execute_list_of_scenarios(s)
#
# ~\OneDrive\REPOS\DavidkaBenAvraham\hypotez\suppliers\execute_scenarios.py in execute_list_of_scenarios(s, scenario_files)
#      47     for json_file in scenario_files:
#      48         ''' запускаю json файлы один за другим '''
# ---> 49         run_scenario_file(s, json_file)
#      50         s.settings['last_runned_scenario']=json_file
#      51         s.p=[]
#
# ~\OneDrive\REPOS\DavidkaBenAvraham\hypotez\suppliers\execute_scenarios.py in run_scenario_file(suppiler, current_scenario_filename)
#      72     for k,scenario in _s.scenarios.items():
#      73         if not scenario['url'] is None:
# ---> 74             run_scenario(_s, scenario)
#      75
#      76
#
# ~\OneDrive\REPOS\DavidkaBenAvraham\hypotez\suppliers\execute_scenarios.py in run_scenario(s, scenario)
#     141         else: return False
#     142
# --> 143     run(s , scenario)
#     144     _export()
#     145
#
# ~\OneDrive\REPOS\DavidkaBenAvraham\hypotez\suppliers\execute_scenarios.py in run(s, scenario)
#      84
#      85         s.current_scenario = scenario
# ---> 86         s.current_scenario.products_counter = 0
#      87         s.current_scenario.files_counter = 1
#      88
#
# AttributeError: 'dict' object has no attribute 'products_counter'

# %%
d.close()
