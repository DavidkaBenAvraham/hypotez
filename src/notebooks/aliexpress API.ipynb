# %%
import ipywidgets as widgets
from IPython.display import display

from src.suppliers import Supplier
import suppliers.execute_scenarios as execute

s = Supplier(supplier_prefix = 'aliexpress', lang = 'EN')
s.driver.get_url('https://aliexpress.com')
# Out:
# True

# %%
from api_aliexpress import AliexpressApi, models

# %%
def set_api_aliexpress():
    KEY = '34249057'
    SECRET = '4113ee5138cad123571354007d53ba63Hidden'
    TRACKING_ID = '12345'
    aliexpress = AliexpressApi(KEY, SECRET, models.Language.EN, models.Currency.EUR, TRACKING_ID)
    return aliexpress

api_aliexpress = set_api_aliexpress()

# %%
http = "https://www.aliexpress.com/item/1005004779588588.html"
affiliate_links = api_aliexpress.get_affiliate_links('1005004779588588')
# Out:
# ---------------------------------------------------------------------------
# TopException                              Traceback (most recent call last)
# ~\OneDrive\REPOS\DavidkaBenAvraham\hypotez\api_aliexpress\helpers\requests.py in api_request(request, response_name)
#       8     try:
# ----> 9         response = request.getResponse()
#      10     except Exception as error:
#
# ~\OneDrive\REPOS\DavidkaBenAvraham\hypotez\api_aliexpress\skd\api\base.py in getResponse(self, authrize, timeout)
#     274             error.service_host = response.getheader("Location-Host", "")
# --> 275             raise error
#     276         return jsonobj
#
# TopException: errorcode=25 message=Invalid signature subcode=None submsg=None application_host=33.79.139.124 service_host=top033079139124.center.na610
#
# The above exception was the direct cause of the following exception:
#
# ApiRequestException                       Traceback (most recent call last)
# ...

# %%
print
