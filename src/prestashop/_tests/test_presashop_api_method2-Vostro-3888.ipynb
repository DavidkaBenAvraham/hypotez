# %%
# -*- coding: utf-8 -*-
#! /usr/share/projects/hypotez/venv/scripts python
import header
from header import gs
from src.helpers import  logger,  logs_and_errors_decorator,  jprint, pprint
# Out:
# ->INFO 21:07:12 from start: 0:00:00.006000 User {{user_id}} logged in
# 	helpers.logger:<module>:48
# NoneType: None
# ->INFO 21:07:13 from start: 0:00:00.450136 caller: __init__ file: <attrs generated init gs.GlobalSettings>
# 	gs:__init__:72
#
# True

# %%
from src.prestashop_api import PrestaAPIV1 as PrestaAPIV1OdAhad
# https://github.com/DavidkaBenAvraham/prestashop_api

api: PrestaAPIV1OdAhad = \
    PrestaAPIV1OdAhad(gs.prestashop_api['api_domain'],
    gs.prestashop_api['api_key']
    )

# %%
print('Get')
res = api.get('products')
pprint(res)
for p in res['products']['product']:
    print(p['@id'], p['@xlink:href'])
# Out:
# Get
# {'@xmlns:xlink': 'http://www.w3.org/1999/xlink',
#  'products': {'product': [{'@id': '24',
#                            '@xlink:href': 'https://emil-design.com/api/products/24'},
#                           {'@id': '63',
#                            '@xlink:href': 'https://emil-design.com/api/products/63'}]}}
# 24 https://emil-design.com/api/products/24
# 63 https://emil-design.com/api/products/63

# %%
print('Search')
#inp = input("Поиск")
res = api.get('search', {'query': 'Murano', 'language': 1})
pprint(res)

def search():
    if not isinstance(res,list):
        if res['products'] is None:
            print('Нет товара удовлятворяющего условиям поиска')
            return False
    for p in res['products']['product']:
        print(p['@id'], p['@xlink:href'])
search()

# %%
print('Add')
data = {'manufacturer': {'active': 1, 'name': 'Sample Manufacturer'}}  # Delete 'name' to get error
res = api.add('manufacturers', data)['manufacturer']
pprint(res)
id = res['id']
print(id, res['name'])

# %%
print('Add Image')
res = api.add_image('products/49 'ps_logo.png')  # set exists=True to replace image
print(res)

# %%
print('Edit')
data = {'manufacturer': {'id': id, 'name': 'Sample Manufacturer Edited'}}
res = api.edit('manufacturers', data)['manufacturer']
print(res['id'], res['name'])

# %%
print('Delete')
res = api.delete('manufacturers/' + res['id'])
print res
