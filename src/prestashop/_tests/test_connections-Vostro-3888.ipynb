# %%
import sys
import os
path = os.getcwd()[:os.getcwd().rfind(r'\hypotez')+7]
sys.path.append(path)  # Добавляю корневую папку в sys.path
# ----------------
from pathlib import Path
import json
import re
# ----------------

# %%
from src.prestashop import Product
# Out:
# ->INFO 21:07:32 from start: 0:00:00.019000 User {{user_id}} logged in
# 	helpers.logger:<module>:48
# NoneType: None
# ->INFO 21:07:34 from start: 0:00:01.232736 caller: __init__ file: <attrs generated init gs.GlobalSettings>
# 	gs:__init__:72
#
# True

# %% [markdown]
# emil-design.com

# %%
prod = Product()
# Out:
#             ->DEBUG 18:06:43 from start: 0:00:04.463789 Prestashop Сервер responce:[('Connection', 'Keep-Alive'), ('Keep-Alive', 'timeout=5, max=100'), ('access-time', '1686669342'), ('x-powered-by', 'PrestaShop Webservice'), ('psws-version', '1.7.8.9'), ('content-type', 'text/xml;charset=utf-8'), ('execution-time', '0.008'), ('content-sha1', '0977bb879814254f3e702d6d8ab5e137f33b0f2f'), ('date', 'Tue, 13 Jun 2023 15:15:42 GMT'), ('server', 'LiteSpeed'), ('platform', 'hostinger'), ('content-security-policy', 'upgrade-insecure-requests')]
#             	prestashop.Prestashop:__init__:77

# %% [markdown]
# dev.e-cat.co.il

# %%
presta_product = Product.get_product_info(108)
print(presta_product)
# Out:
# ->WARNING 21:07:34 from start: 0:07:01.429058  ==========================================================
# 	prestashop.product:get_product_info:75
#
# {'product': {'active': '1',
#              'additional_delivery_times': '0',
#              'additional_shipping_cost': '0.000000',
#              'advanced_stock_management': '0',
#              'affiliate_short_link': {'language': [{'attrs': {'id': '1'},
#                                                     'value': ''},
#                                                    {'attrs': {'id': '2'},
#                                                     'value': ''},
#                                                    {'attrs': {'id': '3'},
#                                                     'value': ''}]},
#              'affiliate_summary': {'language': [{'attrs': {'id': '1'},
#                                                  'value': ''},
#                                                 {'attrs': {'id': '2'},
#                                                  'value': ''},
#                                                 {'attrs': {'id': '3'},
#                                                  'value': ''}]},
#              'affiliate_summary_2': {'language': [{'attrs': {'id': '1'},
#                                                    'value': ''},
#                                                   {'attrs': {'id': '2'},
#                                                    'value': ''},
#                                                   {'attrs': {'id': '3'},
#                                                    'value': ''}]},
#              'affiliate_text': {'language': [{'attrs': {'id': '1'},
#                                               'value': ''},
#                                              {'attrs': {'id': '2'},
#                                               'value': ''},
#                                              {'attrs': {'id': '3'},
#                                               'value': ''}]},
#              'associations': {'accessories': {'attrs': {'api': 'products',
#                                                         'nodeType': 'product'},
#                                               'value': ''},
#                               'attachments': {'attrs': {'api': 'attachments',
#                                                         'nodeType': 'attachment'},
#                                               'value': ''},
#                               'categories': {'attrs': {'api': 'categories',
#                                                        'nodeType': 'category'},
#                                              'value': ''},
#                               'combinations': {'attrs': {'api': 'combinations',
#                                                          'nodeType': 'combination'},
#                                                'value': ''},
#                               'images': {'attrs': {'api': 'images',
#                                                    'nodeType': 'image'},
#                                          'image': {'id': '68'}},
#                               'product_bundle': {'attrs': {'api': 'products',
#                                                            'nodeType': 'product'},
#                                                  'value': ''},
#                               'product_features': {'attrs': {'api': 'product_features',
#                                                              'nodeType': 'product_feature'},
#                                                    'value': ''},
#                               'product_option_values': {'attrs': {'api': 'product_option_values',
#                                                                   'nodeType': 'product_option_value'},
#                                                         'value': ''},
#                               'stock_availables': {'attrs': {'api': 'stock_availables',
#                                                              'nodeType': 'stock_available'},
#                                                    'stock_available': {'id': '158',
#                                                                        'id_product_attribute': '0'}},
#                               'tags': {'attrs': {'api': 'tags',
#                                                  'nodeType': 'tag'},
#                                        'value': ''}},
#              'available_date': '0000-00-00',
#              'available_for_order': '0',
#              'available_later': {'language': [{'attrs': {'id': '1'},
#                                                'value': ''},
#                                               {'attrs': {'id': '2'},
#                                                'value': ''},
#                                               {'attrs': {'id': '3'},
#                                                'value': ''}]},
#              'available_now': {'language': [{'attrs': {'id': '1'}, 'value': ''},
#                                             {'attrs': {'id': '2'}, 'value': ''},
#                                             {'attrs': {'id': '3'},
#                                              'value': ''}]},
#              'cache_default_attribute': '0',
#              'cache_has_attachments': '0',
#              'cache_is_pack': '0',
#              'condition': 'new',
#              'customizable': '0',
#              'date_add': '2023-07-08 02:24:49',
#              'date_upd': '2023-07-08 02:24:49',
#              'delivery_in_stock': {'language': [{'attrs': {'id': '1'},
#                                                  'value': ''},
#                                                 {'attrs': {'id': '2'},
#                                                  'value': ''},
#                                                 {'attrs': {'id': '3'},
#                                                  'value': ''}]},
#              'delivery_out_stock': {'language': [{'attrs': {'id': '1'},
#                                                   'value': ''},
#                                                  {'attrs': {'id': '2'},
#                                                   'value': ''},
#                                                  {'attrs': {'id': '3'},
#                                                   'value': ''}]},
#              'depth': '0.000000',
#              'description': {'language': [{'attrs': {'id': '1'}, 'value': ''},
#                                           {'attrs': {'id': '2'}, 'value': ''},
#                                           {'attrs': {'id': '3'}, 'value': ''}]},
#              'description_short': {'language': [{'attrs': {'id': '1'},
#                                                  'value': ''},
#                                                 {'attrs': {'id': '2'},
#                                                  'value': ''},
#                                                 {'attrs': {'id': '3'},
#                                                  'value': ''}]},
#              'ean13': '',
#              'ecotax': '0.000000',
#              'height': '0.000000',
#              'id': '108',
#              'id_category_default': '11209',
#              'id_default_combination': {'attrs': {'notFilterable': 'true'},
#                                         'value': '0'},
#              'id_default_image': {'attrs': {'notFilterable': 'true'},
#                                   'value': '68'},
#              'id_manufacturer': '0',
#              'id_shop_default': '1',
#              'id_supplier': '2800',
#              'id_tax': '0',
#              'id_type_redirected': '0',
#              'indexed': '1',
#              'is_virtual': '0',
#              'isbn': '',
#              'link_rewrite': {'language': [{'attrs': {'id': '1'}, 'value': ''},
#                                            {'attrs': {'id': '2'}, 'value': ''},
#                                            {'attrs': {'id': '3'},
#                                             'value': ''}]},
#              'location': '',
#              'low_stock_alert': '0',
#              'low_stock_threshold': '0',
#              'manufacturer_name': {'attrs': {'notFilterable': 'true'},
#                                    'value': ''},
#              'meta_description': {'language': [{'attrs': {'id': '1'},
#                                                 'value': ''},
#                                                {'attrs': {'id': '2'},
#                                                 'value': ''},
#                                                {'attrs': {'id': '3'},
#                                                 'value': ''}]},
#              'meta_keywords': {'language': [{'attrs': {'id': '1'}, 'value': ''},
#                                             {'attrs': {'id': '2'}, 'value': ''},
#                                             {'attrs': {'id': '3'},
#                                              'value': ''}]},
#              'meta_title': {'language': [{'attrs': {'id': '1'}, 'value': ''},
#                                          {'attrs': {'id': '2'}, 'value': ''},
#                                          {'attrs': {'id': '3'}, 'value': ''}]},
#              'minimal_quantity': '0',
#              'mpn': '',
#              'name': {'language': [{'attrs': {'id': '1'},
#                                     'value': "Cá d'Oro Small Glass Vase Hippie "
#                                              'Colored Canes Hand Blown '
#                                              'Murano-Style Art Glass - Model '
#                                              'Oval'},
#                                    {'attrs': {'id': '2'},
#                                     'value': "Cá d'Oro Small Glass Vase Hippie "
#                                              'Colored Canes Hand Blown '
#                                              'Murano-Style Art Glass - Model '
#                                              'Oval'},
#                                    {'attrs': {'id': '3'},
#                                     'value': "Cá d'Oro Small Glass Vase Hippie "
#                                              'Colored Canes Hand Blown '
#                                              'Murano-Style Art Glass - Model '
#                                              'Oval'}]},
#              'new': '',
#              'on_sale': '1',
#              'online_only': '0',
#              'pack_stock_type': '0',
#              'position_in_category': {'attrs': {'notFilterable': 'true'},
#                                       'value': ''},
#              'price': '626.220000',
#              'product_type': '',
#              'quantity': {'attrs': {'notFilterable': 'true'}, 'value': '0'},
#              'quantity_discount': '0',
#              'redirect_type': '',
#              'reference': '2800-B09N53XSQB',
#              'show_condition': '1',
#              'show_price': '1',
#              'state': '1',
#              'supplier_reference': 'B09N53XSQB',
#              'text_fields': '0',
#              'type': {'attrs': {'notFilterable': 'true'}, 'value': 'simple'},
#              'unit_price_ratio': '0.000000',
#              'unity': '',
#              'upc': '',
#              'uploadable_files': '0',
#              'visibility': 'both',
#              'weight': '0.000000',
#              'wholesale_price': '0.000000',
#              'width': '0.000000'}}
# ->WARNING 21:07:34 from start: 0:07:01.455054  ==========================================================
# 	prestashop.product:get_product_info:79
#
# {'@xmlns:xlink': 'http://www.w3.org/1999/xlink',
#  'product': {'active': '1',
#              'additional_delivery_times': '0',
#              'additional_shipping_cost': '0.000000',
#              'advanced_stock_management': '0',
#              'affiliate_short_link': {'language': [{'@id': '1',
#                                                     '@xlink:href': 'https://emil-design.com/api/languages/1'},
#                                                    {'@id': '2',
#                                                     '@xlink:href': 'https://emil-design.com/api/languages/2'},
#                                                    {'@id': '3',
#                                                     '@xlink:href': 'https://emil-design.com/api/languages/3'}]},
#              'affiliate_summary': {'language': [{'@id': '1',
#                                                  '@xlink:href': 'https://emil-design.com/api/languages/1'},
#                                                 {'@id': '2',
#                                                  '@xlink:href': 'https://emil-design.com/api/languages/2'},
#                                                 {'@id': '3',
#                                                  '@xlink:href': 'https://emil-design.com/api/languages/3'}]},
#              'affiliate_summary_2': {'language': [{'@id': '1',
#                                                    '@xlink:href': 'https://emil-design.com/api/languages/1'},
#                                                   {'@id': '2',
#                                                    '@xlink:href': 'https://emil-design.com/api/languages/2'},
#                                                   {'@id': '3',
#                                                    '@xlink:href': 'https://emil-design.com/api/languages/3'}]},
#              'affiliate_text': {'language': [{'@id': '1',
#                                               '@xlink:href': 'https://emil-design.com/api/languages/1'},
#                                              {'@id': '2',
#                                               '@xlink:href': 'https://emil-design.com/api/languages/2'},
#                                              {'@id': '3',
#                                               '@xlink:href': 'https://emil-design.com/api/languages/3'}]},
#              'associations': {'accessories': {'@api': 'products',
#                                               '@nodeType': 'product'},
#                               'attachments': {'@api': 'attachments',
#                                               '@nodeType': 'attachment'},
#                               'categories': {'@api': 'categories',
#                                              '@nodeType': 'category'},
#                               'combinations': {'@api': 'combinations',
#                                                '@nodeType': 'combination'},
#                               'images': {'@api': 'images',
#                                          '@nodeType': 'image',
#                                          'image': {'@xlink:href': 'https://emil-design.com/api/images/products/108/68',
#                                                    'id': '68'}},
#                               'product_bundle': {'@api': 'products',
#                                                  '@nodeType': 'product'},
#                               'product_features': {'@api': 'product_features',
#                                                    '@nodeType': 'product_feature'},
#                               'product_option_values': {'@api': 'product_option_values',
#                                                         '@nodeType': 'product_option_value'},
#                               'stock_availables': {'@api': 'stock_availables',
#                                                    '@nodeType': 'stock_available',
#                                                    'stock_available': {'@xlink:href': 'https://emil-design.com/api/stock_availables/158',
#                                                                        'id': '158',
#                                                                        'id_product_attribute': '0'}},
#                               'tags': {'@api': 'tags', '@nodeType': 'tag'}},
#              'available_date': '0000-00-00',
#              'available_for_order': '0',
#              'available_later': {'language': [{'@id': '1',
#                                                '@xlink:href': 'https://emil-design.com/api/languages/1'},
#                                               {'@id': '2',
#                                                '@xlink:href': 'https://emil-design.com/api/languages/2'},
#                                               {'@id': '3',
#                                                '@xlink:href': 'https://emil-design.com/api/languages/3'}]},
#              'available_now': {'language': [{'@id': '1',
#                                              '@xlink:href': 'https://emil-design.com/api/languages/1'},
#                                             {'@id': '2',
#                                              '@xlink:href': 'https://emil-design.com/api/languages/2'},
#                                             {'@id': '3',
#                                              '@xlink:href': 'https://emil-design.com/api/languages/3'}]},
#              'cache_default_attribute': '0',
#              'cache_has_attachments': '0',
#              'cache_is_pack': '0',
#              'condition': 'new',
#              'customizable': '0',
#              'date_add': '2023-07-08 02:24:49',
#              'date_upd': '2023-07-08 02:24:49',
#              'delivery_in_stock': {'language': [{'@id': '1',
#                                                  '@xlink:href': 'https://emil-design.com/api/languages/1'},
#                                                 {'@id': '2',
#                                                  '@xlink:href': 'https://emil-design.com/api/languages/2'},
#                                                 {'@id': '3',
#                                                  '@xlink:href': 'https://emil-design.com/api/languages/3'}]},
#              'delivery_out_stock': {'language': [{'@id': '1',
#                                                   '@xlink:href': 'https://emil-design.com/api/languages/1'},
#                                                  {'@id': '2',
#                                                   '@xlink:href': 'https://emil-design.com/api/languages/2'},
#                                                  {'@id': '3',
#                                                   '@xlink:href': 'https://emil-design.com/api/languages/3'}]},
#              'depth': '0.000000',
#              'description': {'language': [{'@id': '1',
#                                            '@xlink:href': 'https://emil-design.com/api/languages/1'},
#                                           {'@id': '2',
#                                            '@xlink:href': 'https://emil-design.com/api/languages/2'},
#                                           {'@id': '3',
#                                            '@xlink:href': 'https://emil-design.com/api/languages/3'}]},
#              'description_short': {'language': [{'@id': '1',
#                                                  '@xlink:href': 'https://emil-design.com/api/languages/1'},
#                                                 {'@id': '2',
#                                                  '@xlink:href': 'https://emil-design.com/api/languages/2'},
#                                                 {'@id': '3',
#                                                  '@xlink:href': 'https://emil-design.com/api/languages/3'}]},
#              'ean13': None,
#              'ecotax': '0.000000',
#              'height': '0.000000',
#              'id': '108',
#              'id_category_default': {'#text': '11209',
#                                      '@xlink:href': 'https://emil-design.com/api/categories/11209'},
#              'id_default_combination': {'#text': '0', '@notFilterable': 'true'},
#              'id_default_image': {'#text': '68',
#                                   '@notFilterable': 'true',
#                                   '@xlink:href': 'https://emil-design.com/api/images/products/108/68'},
#              'id_manufacturer': '0',
#              'id_shop_default': '1',
#              'id_supplier': {'#text': '2800',
#                              '@xlink:href': 'https://emil-design.com/api/suppliers/2800'},
#              'id_tax': '0',
#              'id_type_redirected': '0',
#              'indexed': '1',
#              'is_virtual': '0',
#              'isbn': None,
#              'link_rewrite': {'language': [{'@id': '1',
#                                             '@xlink:href': 'https://emil-design.com/api/languages/1'},
#                                            {'@id': '2',
#                                             '@xlink:href': 'https://emil-design.com/api/languages/2'},
#                                            {'@id': '3',
#                                             '@xlink:href': 'https://emil-design.com/api/languages/3'}]},
#              'location': None,
#              'low_stock_alert': '0',
#              'low_stock_threshold': '0',
#              'manufacturer_name': {'@notFilterable': 'true'},
#              'meta_description': {'language': [{'@id': '1',
#                                                 '@xlink:href': 'https://emil-design.com/api/languages/1'},
#                                                {'@id': '2',
#                                                 '@xlink:href': 'https://emil-design.com/api/languages/2'},
#                                                {'@id': '3',
#                                                 '@xlink:href': 'https://emil-design.com/api/languages/3'}]},
#              'meta_keywords': {'language': [{'@id': '1',
#                                              '@xlink:href': 'https://emil-design.com/api/languages/1'},
#                                             {'@id': '2',
#                                              '@xlink:href': 'https://emil-design.com/api/languages/2'},
#                                             {'@id': '3',
#                                              '@xlink:href': 'https://emil-design.com/api/languages/3'}]},
#              'meta_title': {'language': [{'@id': '1',
#                                           '@xlink:href': 'https://emil-design.com/api/languages/1'},
#                                          {'@id': '2',
#                                           '@xlink:href': 'https://emil-design.com/api/languages/2'},
#                                          {'@id': '3',
#                                           '@xlink:href': 'https://emil-design.com/api/languages/3'}]},
#              'minimal_quantity': '0',
#              'mpn': None,
#              'name': {'language': [{'#text': "Cá d'Oro Small Glass Vase Hippie "
#                                              'Colored Canes Hand Blown '
#                                              'Murano-Style Art Glass - Model '
#                                              'Oval',
#                                     '@id': '1',
#                                     '@xlink:href': 'https://emil-design.com/api/languages/1'},
#                                    {'#text': "Cá d'Oro Small Glass Vase Hippie "
#                                              'Colored Canes Hand Blown '
#                                              'Murano-Style Art Glass - Model '
#                                              'Oval',
#                                     '@id': '2',
#                                     '@xlink:href': 'https://emil-design.com/api/languages/2'},
#                                    {'#text': "Cá d'Oro Small Glass Vase Hippie "
#                                              'Colored Canes Hand Blown '
#                                              'Murano-Style Art Glass - Model '
#                                              'Oval',
#                                     '@id': '3',
#                                     '@xlink:href': 'https://emil-design.com/api/languages/3'}]},
#              'new': None,
#              'on_sale': '1',
#              'online_only': '0',
#              'pack_stock_type': '0',
#              'position_in_category': {'@notFilterable': 'true'},
#              'price': '626.220000',
#              'product_type': None,
#              'quantity': {'#text': '0', '@notFilterable': 'true'},
#              'quantity_discount': '0',
#              'redirect_type': None,
#              'reference': '2800-B09N53XSQB',
#              'show_condition': '1',
#              'show_price': '1',
#              'state': '1',
#              'supplier_reference': 'B09N53XSQB',
#              'text_fields': '0',
#              'type': {'#text': 'simple', '@notFilterable': 'true'},
#              'unit_price_ratio': '0.000000',
#              'unity': None,
#              'upc': None,
#              'uploadable_files': '0',
#              'visibility': 'both',
#              'weight': '0.000000',
#              'wholesale_price': '0.000000',
#              'width': '0.000000'}}
# ->WARNING 21:07:34 from start: 0:07:01.499054  ==========================================================
# 	prestashop.product:get_product_info:83
#
# ({'product': {'id': '108', 'id_manufacturer': '0', 'id_supplier': '2800', 'id_category_default': '11209', 'new': '', 'cache_default_attribute': '0', 'id_default_image': {'attrs': {'notFilterable': 'true'}, 'value': '68'}, 'id_default_combination': {'attrs': {'notFilterable': 'true'}, 'value': '0'}, 'id_tax': '0', 'position_in_category': {'attrs': {'notFilterable': 'true'}, 'value': ''}, 'manufacturer_name': {'attrs': {'notFilterable': 'true'}, 'value': ''}, 'quantity': {'attrs': {'notFilterable': 'true'}, 'value': '0'}, 'type': {'attrs': {'notFilterable': 'true'}, 'value': 'simple'}, 'id_shop_default': '1', 'reference': '2800-B09N53XSQB', 'supplier_reference': 'B09N53XSQB', 'location': '', 'width': '0.000000', 'height': '0.000000', 'depth': '0.000000', 'weight': '0.000000', 'quantity_discount': '0', 'ean13': '', 'isbn': '', 'upc': '', 'mpn': '', 'cache_is_pack': '0', 'cache_has_attachments': '0', 'is_virtual': '0', 'state': '1', 'additional_delivery_times': '0', 'delivery_in_stock': {'language': [{'attrs': {'id': '1'}, 'value': ''}, {'attrs': {'id': '2'}, 'value': ''}, {'attrs': {'id': '3'}, 'value': ''}]}, 'delivery_out_stock': {'language': [{'attrs': {'id': '1'}, 'value': ''}, {'attrs': {'id': '2'}, 'value': ''}, {'attrs': {'id': '3'}, 'value': ''}]}, 'product_type': '', 'on_sale': '1', 'online_only': '0', 'ecotax': '0.000000', 'minimal_quantity': '0', 'low_stock_threshold': '0', 'low_stock_alert': '0', 'price': '626.220000', 'wholesale_price': '0.000000', 'unity': '', 'unit_price_ratio': '0.000000', 'additional_shipping_cost': '0.000000', 'customizable': '0', 'text_fields': '0', 'uploadable_files': '0', 'active': '1', 'redirect_type': '', 'id_type_redirected': '0', 'available_for_order': '0', 'available_date': '0000-00-00', 'show_condition': '1', 'condition': 'new', 'show_price': '1', 'indexed': '1', 'visibility': 'both', 'advanced_stock_management': '0', 'date_add': '2023-07-08 02:24:49', 'date_upd': '2023-07-08 02:24:49', 'pack_stock_type': '0', 'meta_description': {'language': [{'attrs': {'id': '1'}, 'value': ''}, {'attrs': {'id': '2'}, 'value': ''}, {'attrs': {'id': '3'}, 'value': ''}]}, 'meta_keywords': {'language': [{'attrs': {'id': '1'}, 'value': ''}, {'attrs': {'id': '2'}, 'value': ''}, {'attrs': {'id': '3'}, 'value': ''}]}, 'meta_title': {'language': [{'attrs': {'id': '1'}, 'value': ''}, {'attrs': {'id': '2'}, 'value': ''}, {'attrs': {'id': '3'}, 'value': ''}]}, 'link_rewrite': {'language': [{'attrs': {'id': '1'}, 'value': ''}, {'attrs': {'id': '2'}, 'value': ''}, {'attrs': {'id': '3'}, 'value': ''}]}, 'name': {'language': [{'attrs': {'id': '1'}, 'value': "Cá d'Oro Small Glass Vase Hippie Colored Canes Hand Blown Murano-Style Art Glass - Model Oval"}, {'attrs': {'id': '2'}, 'value': "Cá d'Oro Small Glass Vase Hippie Colored Canes Hand Blown Murano-Style Art Glass - Model Oval"}, {'attrs': {'id': '3'}, 'value': "Cá d'Oro Small Glass Vase Hippie Colored Canes Hand Blown Murano-Style Art Glass - Model Oval"}]}, 'description': {'language': [{'attrs': {'id': '1'}, 'value': ''}, {'attrs': {'id': '2'}, 'value': ''}, {'attrs': {'id': '3'}, 'value': ''}]}, 'description_short': {'language': [{'attrs': {'id': '1'}, 'value': ''}, {'attrs': {'id': '2'}, 'value': ''}, {'attrs': {'id': '3'}, 'value': ''}]}, 'available_now': {'language': [{'attrs': {'id': '1'}, 'value': ''}, {'attrs': {'id': '2'}, 'value': ''}, {'attrs': {'id': '3'}, 'value': ''}]}, 'available_later': {'language': [{'attrs': {'id': '1'}, 'value': ''}, {'attrs': {'id': '2'}, 'value': ''}, {'attrs': {'id': '3'}, 'value': ''}]}, 'affiliate_short_link': {'language': [{'attrs': {'id': '1'}, 'value': ''}, {'attrs': {'id': '2'}, 'value': ''}, {'attrs': {'id': '3'}, 'value': ''}]}, 'affiliate_text': {'language': [{'attrs': {'id': '1'}, 'value': ''}, {'attrs': {'id': '2'}, 'value': ''}, {'attrs': {'id': '3'}, 'value': ''}]}, 'affiliate_summary': {'language': [{'attrs': {'id': '1'}, 'value': ''}, {'attrs': {'id': '2'}, 'value': ''}, {'attrs': {'id': '3'}, 'value': ''}]}, 'a ...
