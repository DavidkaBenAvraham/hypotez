# %%
import header
from header import jprint, pprint
from header import gs
from header import PrestaAPIV1,PrestaAPIV2,PrestaAPIV3
# Out:
# Master password for keepass database: ········
# NoneType: None
# 2024-02-07 05:39:42,601 - ERROR - Error v2
# NoneType: None

# %%
pprint(PrestaAPIV3)

# %%
PrestaAPIV3.ping()
# Out:
# True

# %%
res = PrestaAPIV3.read('products','24',display='[id,name]')
# Out:
# send: b'GET /api/products/24?language=1&io_format=JSON&output_format=JSON&display=%5Bid%2Cname%5D&id=GET HTTP/1.1\r\nHost: emil-design.com\r\nUser-Agent: python-requests/2.31.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\nContent-Type: application/json\r\nAuthorization: Basic S1VaVDE5NTc0RkRBNEc4NVNYTDNMVlZHMkg5UzVLQkE6\r\n\r\n'
# reply: 'HTTP/1.1 404 Not Found\r\n'
# header: Server: hcdn
# header: Date: Wed, 07 Feb 2024 03:39:57 GMT
# header: Content-Length: 0
# header: Connection: keep-alive
# header: access-time: 1707277197
# header: x-powered-by: PrestaShop Webservice
# header: psws-version: 1.7.8.9
# header: execution-time: 0.01
# header: set-cookie: PrestaShop-d704162411a1a680695ef6bf1cbfb651=...; expires=Tue, 27-Feb-2024 03:39:57 GMT; Max-Age=1728000; path=/; domain=emil-design.com; secure; HttpOnly; SameSite=Lax
# header: platform: hostinger
# header: content-security-policy: upgrade-insecure-requests
# header: x-turbo-charged-by: LiteSpeed
# ...

# %%
print(res)

# %%
products = PrestaAPIV3.read('products',[104,105])
