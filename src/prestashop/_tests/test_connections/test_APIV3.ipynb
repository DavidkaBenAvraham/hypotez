# %%
import header
from header import jprint, pprint
from header import \
    gs, \
    PrestaAPIV1,PrestaAPIV2,PrestaAPIV3

# %%
pprint(PrestaAPIV3)
# Out:
# <presta_python_api_v3.core.Prestashop object at 0x0000015197A40B10>

# %%
PrestaAPIV3.ping()
# Out:
# True

# %%
res = PrestaAPIV3.read('products','24',display='[id,name]')
# Out:
# send: b'GET /api/products/24?language=1&io_format=JSON&output_format=JSON&display=%5Bid%2Cname%5D&id=GET HTTP/1.1\r\nHost: emil-design.com\r\nUser-Agent: python-requests/2.30.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\nContent-Type: application/json\r\nAuthorization: Basic S1VaVDE5NTc0RkRBNEc4NVNYTDNMVlZHMkg5UzVLQkE6\r\n\r\n'
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Connection: Keep-Alive
# header: Keep-Alive: timeout=5, max=100
# header: access-time: 1688901739
# header: x-powered-by: PrestaShop Webservice
# header: psws-version: 1.7.8.9
# header: content-type: application/json
# header: execution-time: 0.086
# header: content-sha1: baa4a7ba5a6f4d1a89960687f19a03b692bcf5d3
# header: set-cookie: PrestaShop-d704162411a1a680695ef6bf1cbfb651=...; expires=Sat, 29-Jul-2023 11:22:19 GMT; Max-Age=1728000; path=/; domain=emil-design.com; secure; HttpOnly; SameSite=Lax
# header: content-length: 82
# header: content-encoding: gzip
# header: vary: Accept-Encoding
# header: date: Sun, 09 Jul 2023 11:22:19 GMT
# header: server: LiteSpeed
# header: platform: hostinger
# header: content-security-policy: upgrade-insecure-requests
# header: alt-svc: h3=":443"; ma=2592000, h3-29=":443"; ma=2592000, h3-Q050=":443"; ma=2592000, h3-Q046=":443"; ma=2592000, h3-Q043=":443"; ma=2592000, quic=":443"; ma=2592000; v="43,46"

# %%
print(res)
# Out:
# {'products': [{'id': 24, 'name': 'We provide delivery services'}]}

# %%
products = PrestaAPIV3.read('products',[104,105])
# Out:
# send: b'GET /api/products/%5B104,%20105%5D?language=1&io_format=JSON&output_format=JSON&display=full&id=GET HTTP/1.1\r\nHost: emil-design.com\r\nUser-Agent: python-requests/2.30.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\nContent-Type: application/json\r\nCookie: PrestaShop-d704162411a1a680695ef6bf1cbfb651=...\r\nAuthorization: Basic S1VaVDE5NTc0RkRBNEc4NVNYTDNMVlZHMkg5UzVLQkE6\r\n\r\n'
# reply: 'HTTP/1.1 404 Not Found\r\n'
# header: Connection: Keep-Alive
# header: Keep-Alive: timeout=5, max=100
# header: access-time: 1688901905
# header: x-powered-by: PrestaShop Webservice
# header: psws-version: 1.7.8.9
# header: content-type:
# header: execution-time: 0.017
# header: content-length: 0
# header: date: Sun, 09 Jul 2023 11:25:05 GMT
# header: server: LiteSpeed
# header: platform: hostinger
# header: content-security-policy: upgrade-insecure-requests
# header: alt-svc: h3=":443"; ma=2592000, h3-29=":443"; ma=2592000, h3-Q050=":443"; ma=2592000, h3-Q046=":443"; ma=2592000, h3-Q043=":443"; ma=2592000, quic=":443"; ma=2592000; v="43,46"
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\OneDrive\REPOS\hypotez\venv\Lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File C:\Program Files\Python311\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File C:\Program Files\Python311\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File C:\Program Files\Python311\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 products = PrestaAPIV3.read('products',[104,105])
#
# File ~\OneDrive\REPOS\hypotez\venv\Lib\site-packages\presta_python_api_v3\core.py:350, in Prestashop.read(self, resource, _id, display)
#     338 def read(self,resource:str,_id:str,display:str='full') -> dict:
#     339     """get one result from src.prestashop with options .
#     340     for more details check the official doc \n
#     341     https://devdocs.prestashop-project.org/1.7/webservice/tutorials/advanced-use/additional-list-parameters/
#    (...)
#     348         dict : result of get request
#     349     """
# --> 350     return self._exec(resource,_id,'GET',display=display)
#
# File ~\OneDrive\REPOS\hypotez\venv\Lib\site-packages\presta_python_api_v3\core.py:280, in Prestashop._exec(self, resource, _id, ids, method, data, _headers, display, _filter, sort, limit)
#     278     if response.content == b'' and response.status_code == 200:
#     279         return True
# --> 280     self._error(response.status_code,response.json())
#     281     return response.json()
#     283 headers = {'Content-Type': 'text/xml'}
#
# File ~\OneDrive\REPOS\hypotez\venv\Lib\site-packages\requests\models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
