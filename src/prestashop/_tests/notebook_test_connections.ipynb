# %%
import notebook_header
from notebook_header import pprint, jprint, logger, j_dumps, j_loads, \
Driver, execute_locator, Supplier, Product, ProductFields, SN, SF, Path
# Out:
# Master password for keepass database: ········
# NoneType: None
# 2024-01-29 19:55:54,458 - ERROR - Error v2
# NoneType: None

# %% [markdown]
# emil-design.com

# %%
p = Product()

# %% [markdown]
# dev.e-cat.co.il

# %%
presta_product = p.get_list_products_from_prestashop()
#pprint(presta_product)

# %%
schema = p.get_product_schema_from_prestashop()
# Out:
# -------------------------------------------------------------------------
# AttributeError                          Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 schema = p.get_product_schema_from_prestashop()
#
# File ~\Documents\repos\hypotez\src\prestashop\product.py:231, in PrestaProduct.get_product_schema_from_prestashop(self, api_method)
#     229 params = 'products'
#     230 response = PrestaAPIV1.get(params)
# --> 231 if response.status != 200:
#     232     logger.error(f'''Ошибка при выполнении запроса: {response}''')
#     233     return False
#
# AttributeError: 'dict' object has no attribute 'status'
