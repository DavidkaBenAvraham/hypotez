# %%
import notebook_header
from notebook_header import start_supplier, pprint, jprint, logger, j_dumps, j_loads, \
Driver, execute_locator, Supplier, Product, ProductFields, SN, SF, Path
from src.prestashop import PrestaProduct
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import notebook_header
#       2 from notebook_header import start_supplier, pprint, jprint, logger, j_dumps, j_loads, \
#       3 Driver, execute_locator, Supplier, Product, ProductFields, SN, SF, Path
#       4 from src.prestashop import PrestaProduct
#
# ModuleNotFoundError: No module named 'notebook_header'

# %% [markdown]
# emil-design.com

# %%
prod = Product()

# %% [markdown]
# dev.e-cat.co.il

# %%
presta_product = Product.get_product_info(108)
print(presta_product)
