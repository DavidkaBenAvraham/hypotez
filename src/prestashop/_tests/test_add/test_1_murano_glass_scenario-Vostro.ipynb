# %% [markdown]
# ### Прогоны тестов на добавление товаров со стороны модуля <font style="color:green;"><b><i>prestashop</i></b></font>

# %% [markdown]
# # <a id='toc1_'></a>[Amazon тест](#toc0_)

# %% [markdown]
# ## `Murano Glass` - Прогоняю весь сценарий на добавление товаров со страницы категории
# ## Для корркетной работы этого сценария я переопределяю локаторы для товаров из категории по url `test_url_4`
# есть проблема с локаторами для разных типов товара: `new` и `ref`
# в частности есть проблема с нахождением цены.

# %%
from pathlib import Path
from typing import Union
import header
from header import gs, \
            logger,  logs_and_errors_decorator,  jprint, pprint, \
            SN, SF, \
            Product, ProductFields, \
            PrestaProduct, \
            PrestaAPIV1, PrestaAPIV2, \
            PrestaShopWebServiceError, \
            upload_image, \
            Supplier, start_supplier


supplier_prefix = 'amazon'
s = start_supplier(supplier_prefix)
""" s - на протяжении всего кода означает класс `Supplier` """

print(" Можно продолжать ")

from dict_scenarios import scenario
s.current_scenario = scenario['Murano Glass']

# -------------- сокращения -------
l = s.reread_locators('product')
d = s.driver
_ = d.execute_locator
# --------------------------------

# %%
test_url_4 = r"https://www.amazon.com/C%C3%A1-dOro-Hippie-Colored-Murano-Style/dp/B09N53XSQB/ref=sr_1_1_sspa?crid=24Q0ZZYVNOQMP&keywords=Art+Deco+murano+glass&qid=1687277030&sprefix=art+deco+murano+glass%2Caps%2C230&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&psc=1"
test_url_5 = r"https://www.amazon.com/Luxury-Lane-Sommerso-Centerpiece-Decoration/dp/B0BSZBF8NJ/ref=sr_1_3_sspa?c=ts&keywords=Vases&qid=1688326048&s=furniture&sr=1-3-spons&ts_id=3745451&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1"
d.get_url(test_url_4)
# Out:
# True

# %% [markdown]
# _______________________________________________
# ## <a id='toc1_3_'></a>[Поля товара](#toc0_)

# %% [markdown]
# `grab_product_page` <p>Это функция из модуля <font color="11073B"> suppliers.amazon.grabber</font>
# Ее можно тестировать.
# <h6>Не забудь!</h6>
# <font color='red'><b>Глявное - не забыть потом синхронизирoвать в suppliers.amazon.grabber</b><font></p>

# %% [markdown]
# ### Проверяю наличие товара в бд

# %%
l = s.reread_locators('product')
ASIN = _(l['ASIN'])
product_reference = f"{s.supplier_id}-{ASIN}"
response = Product.check_if_product_in_presta_db(product_reference)
pprint(f' Если товар в бд получу id_product, иначе False. Получил: {response}')
# Out:
# ' Если товар в бд получу id_product, иначе False. Получил: 95'

# %%
def grab_product_page(s: Supplier, id_product: int = 0 ) -> ProductFields:
    """ ПОКА ТОЛЬКО ДЛЯ НОВЫХ!!!!! СТРАНИЦ
        Собираю информацию со страницы товара. 
        Важно помнить, что драйвер уже должен быть на
        этой странице
        ---------------
        Attrs:
            s (Supplier)
        @returns
            f (ProductFields) с заполненными полями, else False
    """


    l = s.reread_locators('product')
    d = s.driver
   
    _ = d.execute_locator

    print('Strat local function grabber')

    def add_new_product_stage_1(s: Supplier) -> ProductFields:
        """ Первая стадия добавления нового товара. Заполняю все необходимые поля
            Далее я отправлю их в prestashop и получу обратно ID вновь созданного товара
            На второй стадии, зная ID, я отправлю главную картинку и прочее
        """
        f: ProductFields = ProductFields()
        #product_dict: dict = {}
        #product_dict['product']: dict = dict(f.fields)
    
        """ ID,ASIN,SKU,SUPPLIER SKU """
    

        def _set_defaults() -> bool:
            """ 
            Set defaults for product of supplier
    	    """
            f.active = 1
            f.on_sale = 1
            f.min_qty = 1
            f.low_stock_level = 0
            f.low_stock_threshold = ''
            f.show_price = 1
            f.show_condition = 1
            f.aviable_online_only = 0
            f.advanced_stock_management = 0
            f.state = 1

        def set_price(s, format: str = 'str') -> Union[str,float]:
            """ Привожу денюшку к 
            [ ] float 
            [v] str
            """
            l = s.reread_locators('product')
            raw_price = _(l['price']['new'])[0]
            raw_price = str(raw_price).split('\n')[0]
            return SN.normalize_price(raw_price)
    

        """ Я добавляю в базу данных престашоп товар путем нескольких последовательных действий
        1. Добавляю поля, необходимые для создания нового товара
        2. Получаю `id_product` созданного товара
        3. Используя полученный `id_product` загружаю дефолтную картинку
        4. итд.
        """

        _set_defaults()
        l = s.reread_locators('product')
        ASIN = _(l['ASIN'])
        f.reference = f'{s.supplier_id}-{ASIN}'
        f.supplier_reference = ASIN
        f.price = set_price(s, format = 'str')
        f.name = _(l['name'])[0]
        f.summary = _(l['summary'])[0]
        f.id_supplier = s.supplier_id
        _category_default = list(s.current_scenario['presta_categories']['default_category'].keys())[0]
        f.id_category_default = _category_default
        

        l = s.reread_locators('product')
        affiliate = _(l['affiliate short link'])
        affiliate = affiliate[1][0]
        f.affiliate_short_link = affiliate
        
        #f.link_rewrite = d.current_url.split(f'''/''')[-4]
        #f.link_rewrite = "test-link"

      
        return f

    def fields_4_new_product_stage_2(s: Supplier, f: ProductFields) -> ProductFields:
        """ После того, как я занес новый товар в бд - я получу его id
        Далее я гружу фото и получаю ее id
        Далее я догружаю осталные па
        ----------------------
        Attrs: 
            s (Supplier):
            f (ProductFields): Заполненные на первом этапе поля. Я беру из них только то, что мне надо для апдейта
        @returns
            ProductFields: поля для апдейта
        """
        l = s.reread_locators('product')
        image_url = _(l['Image URLs (x,y,z...)'])[0]
        img = Product.upload_product_default_image(f.id, image_url)
        #f.id_default_image = img_id
        #list_parent_categories = Product.get_parent_categories(f.id_category_default)
        #f.categories = list_parent_categories

        category_ids: list = Product.get_parent_categories(f.id_category_default)
        f.category_ids = category_ids
        Product.update_product_categories_in_prestashop(f.id, category_ids)
        
        return f

    
    
    if id_product == 0:
        f = add_new_product_stage_1(s)
        prod_dict: dict = {'product': f.fields}
        product = Product.add_2_prestashop(prod_dict)
        print("---------------------NEW PRODUCT-----------------------")
        pprint(product)
        id_product = product['id']
        print("---------------------NEW PRODUCT ID-----------------------")
        print(id_product)
    
    f_stage2 = ProductFields()
    f_stage2.id_product = id_product
    
    f_stage2.id_category_default = list(s.current_scenario['presta_categories']['default_category'].keys())[0]
    print("-------------- FIELDS 2------------------------------")
    pprint(f_stage2.fields)
    f_stage2 = fields_4_new_product_stage_2(s, f_stage2)
    prod_dict: dict = {'product': f_stage2.fields}
    #prod_dict: dict = f_stage2.fields
    print("--------------------------------------------")
    pprint(prod_dict)
    print("--------------------------------------------")
    jprint(prod_dict)
    print("--------------------------------------------")
    #prod = Product.update_product_in_prestashop(id_product, prod_dict)
    pass

# %%
product_fields: ProductFields = grab_product_page(s)
# Out:
# Strat local function grabber
# ---------------------NEW PRODUCT-----------------------
# {'active': '1',
#  'additional_delivery_times': None,
#  'additional_shipping_cost': None,
#  'advanced_stock_management': '0',
#  'affiliate_short_link': {'language': [{'@id': '1',
#                                         '@xlink:href': 'https://emil-design.com/api/languages/1'},
#                                        {'@id': '2',
#                                         '@xlink:href': 'https://emil-design.com/api/languages/2'},
#                                        {'@id': '3',
#                                         '@xlink:href': 'https://emil-design.com/api/languages/3'}]},
#  'affiliate_summary': {'language': [{'@id': '1'}, {'@id': '2'}, {'@id': '3'}]},
#  'affiliate_summary_2': {'language': [{'@id': '1'},
#                                       {'@id': '2'},
#                                       {'@id': '3'}]},
#  'affiliate_text': {'language': [{'@id': '1'}, {'@id': '2'}, {'@id': '3'}]},
#  'associations': {'accessories': {'@api': 'products', '@nodeType': 'product'},
#                   'attachments': {'@api': 'attachments',
#                                   '@nodeType': 'attachment'},
#                   'categories': {'@api': 'categories', '@nodeType': 'category'},
#                   'combinations': {'@api': 'combinations',
#                                    '@nodeType': 'combination'},
#                   'images': {'@api': 'images', '@nodeType': 'image'},
#                   'product_bundle': {'@api': 'products',
#                                      '@nodeType': 'product'},
#                   'product_features': {'@api': 'product_features',
#                                        '@nodeType': 'product_feature'},
#                   'product_option_values': {'@api': 'product_option_values',
#                                             '@nodeType': 'product_option_value'},
#                   'stock_availables': {'@api': 'stock_availables',
#                                        '@nodeType': 'stock_available',
#                                        'stock_available': {'@xlink:href': 'https://emil-design.com/api/stock_availables/158',
#                                                            'id': '158',
#                                                            'id_product_attribute': '0'}},
#                   'tags': {'@api': 'tags', '@nodeType': 'tag'}},
#  'available_date': None,
#  'available_for_order': None,
#  'available_later': {'language': [{'@id': '1'}, {'@id': '2'}, {'@id': '3'}]},
#  'available_now': {'language': [{'@id': '1'}, {'@id': '2'}, {'@id': '3'}]},
#  'cache_default_attribute': None,
#  'cache_has_attachments': None,
#  'cache_is_pack': None,
#  'condition': 'new',
#  'customizable': None,
#  'date_add': '2023-07-08 02:24:49',
#  'date_upd': '2023-07-08 02:24:49',
#  'delivery_in_stock': {'language': [{'@id': '1'}, {'@id': '2'}, {'@id': '3'}]},
#  'delivery_out_stock': {'language': [{'@id': '1'}, {'@id': '2'}, {'@id': '3'}]},
#  'depth': None,
#  'description': {'language': [{'@id': '1'}, {'@id': '2'}, {'@id': '3'}]},
#  'description_short': {'language': [{'@id': '1'}, {'@id': '2'}, {'@id': '3'}]},
#  'ean13': None,
#  'ecotax': None,
#  'height': None,
#  'id': '108',
#  'id_category_default': {'#text': '11209',
#                          '@xlink:href': 'https://emil-design.com/api/categories/11209'},
#  'id_default_combination': {'#text': '0', '@notFilterable': 'true'},
#  'id_default_image': {'@notFilterable': 'true'},
#  'id_manufacturer': None,
#  'id_shop_default': '1',
#  'id_supplier': {'#text': '2800',
#                  '@xlink:href': 'https://emil-design.com/api/suppliers/2800'},
#  'id_tax': None,
#  'id_type_redirected': None,
#  'indexed': None,
#  'is_virtual': None,
#  'isbn': None,
#  'link_rewrite': {'language': [{'@id': '1',
#                                 '@xlink:href': 'https://emil-design.com/api/languages/1'},
#                                {'@id': '2',
#                                 '@xlink:href': 'https://emil-design.com/api/languages/2'},
#                                {'@id': '3',
#                                 '@xlink:href': 'https://emil-design.com/api/languages/3'}]},
#  'location': None,
#  'low_stock_alert': None,
#  'low_stock_threshold': None,
#  'manufacturer_name': {'@notFilterable': 'true'},
#  'meta_description': {'language': [{'@id': '1'}, {'@id': '2'}, {'@id': '3'}]},
#  'meta_keywords': {'language': [{'@id': '1'}, {'@id': '2'}, {'@id': '3'}]},
#  'meta_title': {'language': [{'@id': '1'}, {'@id': '2'}, {'@id': '3'}]},
#  'minimal_quantity': None,
#  'mpn': None,
#  'name': {'language': [{'#text': '�', '@id': '1'},
#                        {'#text': '�', '@id': '2'},
#                        {'@id': '3'}]},
#  'new': None,
#  'on_sale': '1',
#  'online_only': None,
#  'pack_stock_type': None,
#  'position_in_category': {'@notFilterable': 'true'},
#  'price': '626.22',
#  'product_type': None,
#  'quantity': {'@notFilterable': 'true'},
#  'quantity_discount': None,
#  'redirect_type': None,
#  'reference': '2800-B09N53XSQB',
#  'show_condition': '1',
#  'show_price': '1',
#  'state': '1',
#  'supplier_reference': 'B09N53XSQB',
#  'text_fields': None,
#  'type': {'#text': 'simple', '@notFilterable': 'true'},
#  'unit_price_ratio': None,
#  'unity': None,
#  'upc': None,
#  'uploadable_files': None,
#  'visibility': 'both',
#  'weight': None,
#  'wholesale_price': None,
#  'width': None}
# ---------------------NEW PRODUCT ID-----------------------
# 108
# -------------- FIELDS 2------------------------------
# {'id': '108', 'id_category_default': '11209'}
#
#             ->DEBUG 02:07:49 from start: 0:00:21.319534
#         Дефолтное изображение для Images/products/108
#         успешно загруженo
#             	prestashop.images_exec:upload_image:89
# ---------------------------------------------------------------------------
# PrestaShopWebServiceError                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 product_fields: ProductFields = grab_product_page(s)
#
# Cell In[4], line 132, in grab_product_page(s, id_product)
#     130 print("-------------- FIELDS 2------------------------------")
#     131 pprint(f_stage2.fields)
# --> 132 f_stage2 = fields_4_new_product_stage_2(s, f_stage2)
#     133 prod_dict: dict = {'product': f_stage2.fields}
#     134 #prod_dict: dict = f_stage2.fields
#
# Cell In[4], line 110, in grab_product_page.<locals>.fields_4_new_product_stage_2(s, f)
#     108 category_ids: list = Product.get_parent_categories(f.id_category_default)
#     109 f.category_ids = category_ids
# --> 110 Product.update_product_categories_in_prestashop(f.id, category_ids)
#     112 return f
#
# File ~\OneDrive\REPOS\hypotez\product\product.py:160, in Product.update_product_categories_in_prestashop(id_product, category_ids)
#     151 @staticmethod
#     152 def update_product_categories_in_prestashop(id_product: int, category_ids: list) -> Union[int,bool]:
#     153     """
#     154     Update product in prestashop  db via api
#     155     Args:
#    (...)
#     158         id for added product if success, else False
#     159     """
# --> 160     return PrestaProduct.update_categories(id_product, category_ids)
#
# File ~\OneDrive\REPOS\hypotez\prestashop\product.py:148, in Product.update_categories(id_product, category_ids)
#     145 product = PrestaAPIV1.get('products', id_product)
#     146 product['product']['associations']['categories'] = \
#     147     {'categories': [{'id': cat_id} for cat_id in category_ids]}
# --> 148 PrestaAPIV1.edit('products', id_product, product)
#     149 pass
#
# File ~\OneDrive\REPOS\hypotez\venv\Lib\site-packages\prestapyt\prestapyt.py:457, in PrestaShopWebService.edit(self, resource, content, options)
#     455 full_url = "%s%s" % (self._API_DOMAIN, resource)
#     456 if options:
# --> 457     self._validate_query_options(options)
#     458     full_url += "?%s" % (self._options_to_querystring(options),)
#     459 return self.edit_with_url(full_url, content)
#
# File ~\OneDrive\REPOS\hypotez\venv\Lib\site-packages\prestapyt\prestapyt.py:316, in PrestaShopWebService._validate_query_options(self, options)
#     311 unsupported = set([
#     312     param.split('[')[0]
#     313     for param in options
#     314 ]).difference(supported)
#     315 if unsupported:
# --> 316     raise PrestaShopWebServiceError(
#     317         'Unsupported parameters: %s' % (', '.join(tuple(unsupported)),)
#     318     )
#     319 return True
#
# PrestaShopWebServiceError: 'Unsupported parameters: product'

# %%
Product.get_product_info_by_id(82)

# %%
jprint(product_dict)

# %% [markdown]
# # Погоняй до сюда

# %% [markdown]
#  Первая часть теста с добавлением товара в базу данных работает через `PrestaAPIV2.add('products', product_dict)`
# <hr>

# %%
#TODO: Переделать в локатор!
link_rewrite = d.current_url.split(f'''/''')[-4]

link_rewrite = SN.symbols2HTML(link_rewrite)
pprint(link_rewrite)

# %%
pprint(prod['product'])

# %%
test_p = Product.get_product_info_by_id(24)
