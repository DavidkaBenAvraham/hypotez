# %%
from typing import Union
import header
from header import gs, jprint, pprint, Product, ProductFields

# %%
products_list = Product.get_list_products_from_presta()

# %%
#jprint(products_list)

# %%
response = Product.get_product_info(100)
# Out:
# send: b'GET /api/products/100?language=1&io_format=JSON&output_format=JSON&display=full&id=GET HTTP/1.1\r\nHost: emil-design.com\r\nUser-Agent: python-requests/2.30.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\nContent-Type: application/json\r\nAuthorization: Basic S1VaVDE5NTc0RkRBNEc4NVNYTDNMVlZHMkg5UzVLQkE6\r\n\r\n'
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Connection: Keep-Alive
# header: Keep-Alive: timeout=5, max=100
# header: access-time: 1688919730
# header: x-powered-by: PrestaShop Webservice
# header: psws-version: 1.7.8.9
# header: content-type: application/json
# header: execution-time: 0.008
# header: content-sha1: 9d1c896f5e26930e483f764fa52710691bd6f9ac
# header: set-cookie: PrestaShop-d704162411a1a680695ef6bf1cbfb651=...; expires=Sat, 29-Jul-2023 16:22:10 GMT; Max-Age=1728000; path=/; domain=emil-design.com; secure; HttpOnly; SameSite=Lax
# header: content-length: 848
# header: content-encoding: gzip
# header: vary: Accept-Encoding
# header: date: Sun, 09 Jul 2023 16:22:10 GMT
# header: server: LiteSpeed
# header: platform: hostinger
# header: content-security-policy: upgrade-insecure-requests
# header: alt-svc: h3=":443"; ma=2592000, h3-29=":443"; ma=2592000, h3-Q050=":443"; ma=2592000, h3-Q046=":443"; ma=2592000, h3-Q043=":443"; ma=2592000, quic=":443"; ma=2592000; v="43,46"

# %%
product = response['products'][0]
id_product = product['id']
pprint(product)
# Out:
# {'active': '1',
#  'additional_delivery_times': '0',
#  'additional_shipping_cost': '0.000000',
#  'advanced_stock_management': '0',
#  'affiliate_short_link': 'https://amzn.to/44cQ7Ef',
#  'affiliate_summary': '',
#  'affiliate_summary_2': '',
#  'affiliate_text': '',
#  'associations': {'images': [{'id': '60'}],
#                   'stock_availables': [{'id': '150',
#                                         'id_product_attribute': '0'}]},
#  'available_date': '0000-00-00',
#  'available_for_order': '0',
#  'available_later': '',
#  'available_now': '',
#  'cache_default_attribute': '0',
#  'cache_has_attachments': '0',
#  'cache_is_pack': '0',
#  'condition': 'new',
#  'customizable': '0',
#  'date_add': '2023-07-08 01:32:20',
#  'date_upd': '2023-07-08 01:32:20',
#  'delivery_in_stock': '',
#  'delivery_out_stock': '',
#  'depth': '0.000000',
#  'description': '',
#  'description_short': '',
#  'ean13': '',
#  'ecotax': '0.000000',
#  'height': '0.000000',
#  'id': 100,
#  'id_category_default': '11209',
#  'id_default_combination': 0,
#  'id_default_image': '60',
#  'id_manufacturer': '0',
#  'id_shop_default': '1',
#  'id_supplier': '2800',
#  'id_tax': '0',
#  'id_type_redirected': '0',
#  'indexed': '1',
#  'is_virtual': '0',
#  'isbn': '',
#  'link_rewrite': '',
#  'location': '',
#  'low_stock_alert': '0',
#  'low_stock_threshold': '0',
#  'manufacturer_name': False,
#  'meta_description': '',
#  'meta_keywords': '',
#  'meta_title': '',
#  'minimal_quantity': '0',
#  'mpn': '',
#  'name': "Cá d'Oro Small Glass Vase Hippie Colored Canes Hand Blown "
#          'Murano-Style Art Glass - Model Oval',
#  'new': None,
#  'on_sale': '1',
#  'online_only': '0',
#  'pack_stock_type': '0',
#  'position_in_category': '',
#  'price': '626.220000',
#  'product_type': '',
#  'quantity': '0',
#  'quantity_discount': '0',
#  'redirect_type': '',
#  'reference': '2800-B09N53XSQB',
#  'show_condition': '1',
#  'show_price': '1',
#  'state': '1',
#  'supplier_reference': 'B09N53XSQB',
#  'text_fields': '0',
#  'type': 'simple',
#  'unit_price_ratio': '0.000000',
#  'unity': '',
#  'upc': '',
#  'uploadable_files': '0',
#  'visibility': 'both',
#  'weight': '0.000000',
#  'wholesale_price': '0.000000',
#  'width': '0.000000'}

# %%
category_ids = Product.get_parent_categories(product['id_category_default'])
category_ids: list = [category_ids] if isinstance(category_ids,str) else category_ids
category_ids: list = [{'id': id} for id in category_ids]
# Out:
# send: b'GET /api/categories/11209 HTTP/1.1\r\nHost: emil-design.com\r\nUser-Agent: python-requests/2.30.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\nCookie: PrestaShop-d704162411a1a680695ef6bf1cbfb651=...\r\nAuthorization: Basic S1VaVDE5NTc0RkRBNEc4NVNYTDNMVlZHMkg5UzVLQkE6\r\n\r\n'
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Connection: Keep-Alive
# header: Keep-Alive: timeout=5, max=100
# header: access-time: 1688919750
# header: x-powered-by: PrestaShop Webservice
# header: psws-version: 1.7.8.9
# header: content-type: text/xml;charset=utf-8
# header: execution-time: 0.018
# header: content-sha1: f099f3c7188ebd69a2bebc466bf9968946667996
# header: content-length: 909
# header: content-encoding: gzip
# header: vary: Accept-Encoding
# header: date: Sun, 09 Jul 2023 16:22:30 GMT
# header: server: LiteSpeed
# header: platform: hostinger
# header: content-security-policy: upgrade-insecure-requests
# header: alt-svc: h3=":443"; ma=2592000, h3-29=":443"; ma=2592000, h3-Q050=":443"; ma=2592000, h3-Q046=":443"; ma=2592000, h3-Q043=":443"; ma=2592000, quic=":443"; ma=2592000; v="43,46"
# send: b'GET /api/categories/11206 HTTP/1.1\r\nHost: emil-design.com\r\nUser-Agent: python-requests/2.30.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\nCookie: PrestaShop-d704162411a1a680695ef6bf1cbfb651=...\r\nAuthorization: Basic S1VaVDE5NTc0RkRBNEc4NVNYTDNMVlZHMkg5UzVLQkE6\r\n\r\n'
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Connection: Keep-Alive
# header: Keep-Alive: timeout=5, max=100
# header: access-time: 1688919751
# header: x-powered-by: PrestaShop Webservice
# header: psws-version: 1.7.8.9
# header: content-type: text/xml;charset=utf-8
# header: execution-time: 0.009
# header: content-sha1: efb045a189c3a0149e244e459f54565fc26d4d93
# header: content-length: 609
# header: content-encoding: gzip
# header: vary: Accept-Encoding
# header: date: Sun, 09 Jul 2023 16:22:31 GMT
# header: server: LiteSpeed
# header: platform: hostinger
# header: content-security-policy: upgrade-insecure-requests
# send: b'GET /api/categories/11036 HTTP/1.1\r\nHost: emil-design.com\r\nUser-Agent: python-requests/2.30.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\nCookie: PrestaShop-d704162411a1a680695ef6bf1cbfb651=...\r\nAuthorization: Basic S1VaVDE5NTc0RkRBNEc4NVNYTDNMVlZHMkg5UzVLQkE6\r\n\r\n'
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Connection: Keep-Alive
# header: Keep-Alive: timeout=5, max=100
# header: access-time: 1688919751
# header: x-powered-by: PrestaShop Webservice
# header: psws-version: 1.7.8.9
# header: content-type: text/xml;charset=utf-8
# header: execution-time: 0.009
# header: content-sha1: 33324e6eac2e4f8c6eee40e6efa209867cd5a7b5
# header: content-length: 735
# header: content-encoding: gzip
# header: vary: Accept-Encoding
# header: date: Sun, 09 Jul 2023 16:22:31 GMT
# header: server: LiteSpeed
# header: platform: hostinger
# header: content-security-policy: upgrade-insecure-requests
# send: b'GET /api/categories/2 HTTP/1.1\r\nHost: emil-design.com\r\nUser-Agent: python-requests/2.30.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\nCookie: PrestaShop-d704162411a1a680695ef6bf1cbfb651=...\r\nAuthorization: Basic S1VaVDE5NTc0RkRBNEc4NVNYTDNMVlZHMkg5UzVLQkE6\r\n\r\n'
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Connection: Keep-Alive
# header: Keep-Alive: timeout=5, max=100
# header: access-time: 1688919751
# header: x-powered-by: PrestaShop Webservice
# header: psws-version: 1.7.8.9
# header: content-type: text/xml;charset=utf-8
# header: execution-time: 0.009
# header: content-sha1: be330bae3c836fdec06233071e36c3d01be93094
# header: content-length: 665
# header: content-encoding: gzip
# header: vary: Accept-Encoding
# header: date: Sun, 09 Jul 2023 16:22:31 GMT
# header: server: LiteSpeed
# header: platform: hostinger
# header: content-security-policy: upgrade-insecure-requests

# %%
product['associations']['categories']: list = category_ids
product['id_tax'] = 13
product['manufacturer_name'] = ''
product['id_manufacturer'] = 2273
product['available_for_order'] = '1'
if 'manufacturer_name' in product.keys(): del product['manufacturer_name']
if 'low_stock_alert' in product.keys(): del product['low_stock_alert']
if 'low_stock_threshold' in product.keys(): del product['low_stock_threshold']
if 'quantity' in product.keys(): del product['quantity']
if 'additional_delivery_times' in product.keys(): del product['additional_delivery_times']
if 'depth' in product.keys(): del product['depth']
if 'weight' in product.keys(): del product['weight']
if 'height' in product.keys(): del product['height']
if 'width' in product.keys(): del product['width']    
if 'unit_price_ratio' in product.keys(): del product['unit_price_ratio']
if 'new' in product.keys(): del product['new']
if 'minimal_quantity' in product.keys(): del product['minimal_quantity']
if 'text_fields' in product.keys(): del product['text_fields']
if 'uploadable_files' in product.keys(): del product['uploadable_files']
if 'ean13' in product.keys(): del product['ean13']
if 'ecotax' in product.keys(): del product['ecotax']
if 'cache_is_pack' in product.keys(): del product['cache_is_pack']
if 'cache_has_attachments' in product.keys(): del product['cache_has_attachments']
if 'cache_default_attribute' in product.keys(): del product['cache_default_attribute']
if 'advanced_stock_management' in product.keys(): del product['advanced_stock_management']
if 'additional_shipping_cost' in product.keys(): del product['additional_shipping_cost']
if 'wholesale_price' in product.keys(): del product['wholesale_price']
if 'quantity_discount' in product.keys(): del product['quantity_discount']
if 'pack_stock_type' in product.keys(): del product['pack_stock_type']
if 'online_only' in product.keys(): del product['online_only']
if 'is_virtual' in product.keys(): del product['is_virtual']

# %%
edited_product: dict = {'product':
    {
    'id': product['id'],
    'associations':{
        'categories': category_ids
        },
    'price': product['price']
    }
}
pprint(edited_product)
# Out:
# {'product': {'associations': {'categories': [{'id': '11206'},
#                                              {'id': '11036'},
#                                              {'id': '2'}]},
#              'id': 100,
#              'price': '626.220000'}}

# %%
p = Product.update_product_in_prestashop(id_product,edited_product)
# Out:
# send: b'POST /api/products/100?language=1&io_format=JSON&output_format=JSON&display=full HTTP/1.1\r\nHost: emil-design.com\r\nUser-Agent: python-requests/2.30.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\nContent-Type: application/json\r\nCookie: PrestaShop-d704162411a1a680695ef6bf1cbfb651=...\r\nContent-Length: 261\r\nAuthorization: Basic S1VaVDE5NTc0RkRBNEc4NVNYTDNMVlZHMkg5UzVLQkE6\r\n\r\n'
# send: b'<?xml version="1.0" encoding="UTF-8"?><prestashop><product><id>100</id><associations><categories><id>11206</id></categories><categories><id>11036</id></categories><categories><id>2</id></categories></associations><price>626.220000</price></product></prestashop>'
# reply: 'HTTP/1.1 400 Bad Request\r\n'
# header: Connection: Keep-Alive
# header: Keep-Alive: timeout=5, max=100
# header: access-time: 1688919766
# header: x-powered-by: PrestaShop Webservice
# header: psws-version: 1.7.8.9
# header: content-type: application/json
# header: execution-time: 0.022
# header: content-length: 92
# header: content-encoding: gzip
# header: vary: Accept-Encoding
# header: date: Sun, 09 Jul 2023 16:22:46 GMT
# header: server: LiteSpeed
# header: platform: hostinger
# header: content-security-policy: upgrade-insecure-requests
# header: alt-svc: h3=":443"; ma=2592000, h3-29=":443"; ma=2592000, h3-Q050=":443"; ma=2592000, h3-Q046=":443"; ma=2592000, h3-Q043=":443"; ma=2592000, quic=":443"; ma=2592000; v="43,46"
# 'id is forbidden when adding a new resource'

# %%
pprint(p)
# Out:
# {'product': {'active': None,
#              'additional_delivery_times': None,
#              'additional_shipping_cost': None,
#              'advanced_stock_management': None,
#              'affiliate_short_link': '',
#              'affiliate_summary': '',
#              'affiliate_summary_2': '',
#              'affiliate_text': '',
#              'associations': {'images': [{'id': '62'}],
#                               'stock_availables': [{'id': '152',
#                                                     'id_product_attribute': '0'}]},
#              'available_date': None,
#              'available_for_order': None,
#              'available_later': '',
#              'available_now': '',
#              'cache_default_attribute': None,
#              'cache_has_attachments': None,
#              'cache_is_pack': None,
#              'condition': 'new',
#              'customizable': None,
#              'date_add': '2023-07-09 18:56:46',
#              'date_upd': '2023-07-09 18:56:46',
#              'delivery_in_stock': '',
#              'delivery_out_stock': '',
#              'depth': None,
#              'description': '',
#              'description_short': '',
#              'ean13': None,
#              'ecotax': None,
#              'height': None,
#              'id': '102',
#              'id_category_default': '',
#              'id_default_combination': 0,
#              'id_default_image': '62',
#              'id_manufacturer': '',
#              'id_shop_default': '1',
#              'id_supplier': '',
#              'id_tax': '',
#              'id_type_redirected': '',
#              'indexed': None,
#              'is_virtual': None,
#              'isbn': None,
#              'link_rewrite': '',
#              'location': None,
#              'low_stock_alert': None,
#              'low_stock_threshold': None,
#              'manufacturer_name': False,
#              'meta_description': '',
#              'meta_keywords': '',
#              'meta_title': '',
#              'minimal_quantity': None,
#              'mpn': None,
#              'name': '',
#              'new': None,
#              'on_sale': None,
#              'online_only': None,
#              'pack_stock_type': None,
#              'position_in_category': '1',
#              'price': '626.220000',
#              'product_type': None,
#              'quantity': None,
#              'quantity_discount': None,
#              'redirect_type': None,
#              'reference': None,
#              'show_condition': None,
#              'show_price': None,
#              'state': None,
#              'supplier_reference': None,
#              'text_fields': None,
#              'type': 'simple',
#              'unit_price_ratio': None,
#              'unity': None,
#              'upc': None,
#              'uploadable_files': None,
#              'visibility': 'both',
#              'weight': None,
#              'wholesale_price': None,
#              'width': None}}

# %%
img_url = 'https://m.media-amazon.com/images/I/51ojk3Tf1PL._AC_SX522_.jpg'

# %%
response = Product.upload_product_default_image(60, img_url)
# Out:
#             ->DEBUG 21:07:39 from start: 0:01:59.689614
#         Дефолтное изображение для Images/products/60
#         успешно загруженo
#             	prestashop.images_exec:upload_image:88

# %%
content = response['prestashop']
pprint(content['image']['id'])
# Out:
# '40'

# %%
print(products_list)
# Out:
# {'@xmlns:xlink': 'http://www.w3.org/1999/xlink', 'products': {'product': [{'@id': '24', '@xlink:href': 'https://emil-design.com/api/products/24'}, {'@id': '60', '@xlink:href': 'https://emil-design.com/api/products/60'}]}}
