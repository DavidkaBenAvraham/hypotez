# %% [markdown]
# # Модуль для эксперементов с полями товара Алиехпресс

# %% [markdown]
# ## Стартовые установки и импорты

# %%
import sys
import os
from pathlib import Path

# Добавляю к переменной путей в ОС (sys.path) путь к корню проекта и путь к файлам программы
dir_root : Path = Path (os.getcwd()[:os.getcwd().rfind('hypotez')+8])
print (dir_root)
sys.path.append (str (dir_root) )  # Добавляю корневую папку в sys.path
dir_src = Path (dir_root, 'src')
print (dir_src)
sys.path.append (str (dir_src) )  # Добавляю рабочую папку в sys.path 


from suppliers import Supplier
from product import Product, ProductFields
from tools import StringFormatter as SF, StringNormalizer as SN, StringValidator as SV
from helpers import logger, logs_and_errors_decorator, pprint, jprint
# Out:
# C:\Users\user\Documents\repos\hypotez
# C:\Users\user\Documents\repos\hypotez\src
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 14
#      10 print (dir_src)
#      11 sys.path.append (str (dir_src) )  # Добавляю рабочую папку в sys.path
# ---> 14 from suppliers import Supplier
#      15 from product import Product, ProductFields
#      16 from tools import StringFormatter as SF, StringNormalizer as SN, StringValidator as SV
#
# File ~\Documents\repos\hypotez\src\suppliers\__init__.py:24
#       1 """! @~russian Модуль `suppliers` oтвечает за все манипуляции с товаром относительно поставщика.
#       2
#       3 @details
#    (...)
#      18  @file
#      19 """
#      21 # -*- coding: utf-8 -*-
#      22 #! /usr/share/projects/hypotez/venv/scripts python
# ---> 24 from .supplier import Supplier
#
# File ~\Documents\repos\hypotez\src\suppliers\supplier.py:41
#      39 from src.io_interface import j_loads, j_dumps
#      40 from src.helpers import logger,  logs_and_errors_decorator, jprint, pprint
# ---> 41 from src.webdriver import Driver
#      42 from src.scenarios import executor
#      43 # ----------------------------------
#
# File ~\Documents\repos\hypotez\src\webdriver\__init__.py:24
#       1 """! @~russian
#       2 @brief Модуль вебдрайвера
#       3 @details Я объединил в класс `Driver` все, что взаимодействует по протоколу `HTTP`:
#    (...)
#      18   - .Driver
#      19 """
#      21 # -*- coding: utf-8 -*-
#      22 #! /usr/share/projects/hypotez/venv/scripts python
# ---> 24 from .Driver import Driver
#
# File ~\Documents\repos\hypotez\src\webdriver\Driver.py:211
#     201 from . import execute_locator, js
#     202 # -------------------------------
#     203
#     204     #####################################################################
#    (...)
#     207     #                                                                   #
#     208     #####################################################################
# --> 211 if gs.webdriver == 'firefox':
#     212     from .Firefox import Firefox as WebDriver #! <- Firefox """
#     213 elif gs.webdriver == 'edge':
#
# AttributeError: 'bool' object has no attribute 'webdriver'

# %% [markdown]
# ## Поставщик
# ### С поставщиком загрузится и его вебдрайвер. Открытие окна браузера займет некоторое время

# %%
def start_supplier(supplier_prefix: str = 'aliexpress', scenario_language: str = 'en' ):
    """ Старт поставщика """
    params: dict = \
    {
        'supplier_prefix': supplier_prefix,
        'scenario_language': scenario_language
    }
    
    return Supplier(**params)
s = start_supplier('aliexpress')

# %% [markdown]
# ## тестовыe сценарии и набор URL

# %%
test_scenario: dict = {
  "category ID on site": 40000002781737,
  "brand": "APPLE",
  "url": "https://hi5group.aliexpress.com/store/group/iPhone-13-13-mini/1053035_40000002781737.html",
  "active": True,
  "condition": "new",
  "presta_categories": {
    "template": {
      "apple": "iPhone 13"
    },
      "default_category": { "11209": "MURANO GLASS" }
  },
  
  "product combinations": [
    "bundle",
    "color"
  ]
}

test_products_list: list = ['https://s.click.aliexpress.com/e/_oFLpkfz', 
                        'https://s.click.aliexpress.com/e/_oE5V3d9', 
                        'https://s.click.aliexpress.com/e/_oDnvttN', 
                        'https://s.click.aliexpress.com/e/_olWWQCP', 
                        'https://s.click.aliexpress.com/e/_ok0xeMn']

# %% [markdown]
# ### Установки для работы с товаром.
#
# - `p` - инстанс класса `Product` <br/>
# - `_l` - словарь локаторов вебэлементов. <br/>
# Локаторы настроены каждый на свой элемент страницы `html`. Вебдрайвер `Driver` через локаторы исследует целевую страницу<br>
# - `_d` инстанс класса `Driver`, который подключен к этому поставщику
# - `_f` инстанс класса `ProductFields`, который принимая значения от `_d` переводит его в словарь полей формата `API Prestashop`

# %%
s.current_scenario = test_scenario
p = Product(supplier = s)
_l : dict = s.locators['product']
_d = s.driver
_f = p.product_fields

# %% [markdown]
# #### перехожу по URL

# %%
_d.get_url(test_products_list[0])

# %% [markdown]
# #### собираю поля

# %%
_f.supplier_reference = _d.current_url.split('/')[-1].split('.')[0]
_f.reference = f'''{s.supplier_id}-{_f.supplier_reference}'''
#_f.name = SN.normalize_product_name ( _d.execute_locator( _l['name'] )[0])
_f.name =  _d.execute_locator( _l['name'] )[0]

_category_default = list(s.current_scenario['presta_categories']['default_category'].keys())[0]
_f.id_category_default = _category_default

_f.id_lang
_f.id_manufacturer = s.current_scenario['brand']
_f.id_shop_default
_f.id_supplier = s.supplier_id
_f.id_tax = 13
_f.affiliate_short_link = _d.execute_locator (_l['affiliate_short_link'])

# %%
pprint( _f.name['language'][0]['value'] )

# %%
pprint ( _f.id_category_default)
