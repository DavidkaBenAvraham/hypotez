# %%
import sys
import os
from pathlib import Path
dir_root : Path = Path (os.getcwd()[:os.getcwd().rfind('hypotez')+11])
sys.path.append (str (dir_root) )  # Добавляю корневую папку в sys.path
from suppliers import Supplier
pass
# Out:
# OK
# ->ERROR 19:12:01 from start: 0:00:09.003755 key 'keypass_openai_api' not found
# 	settings.gs:__init__:211
# ->ERROR 19:12:01 from start: 0:00:09.362747 key 'db.emil-design.com' as error 'ftp'
# 	settings.gs:__init__:241
# ->ERROR 19:12:02 from start: 0:00:09.720396 key 'ftp.emil-design.com' as error 'ftp'
# 	settings.gs:__init__:247
# ->ERROR 19:12:02 from start: 0:00:10.080010 key 'ftp.emil-design.com' as error 'smtp'
# 	settings.gs:__init__:254
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 6
#       4 dir_root : Path = Path (os.getcwd()[:os.getcwd().rfind('hypotez')+11])
#       5 sys.path.append (str (dir_root) )  # Добавляю корневую папку в sys.path
# ----> 6 from suppliers import Supplier
#       7 pass
#
# File c:\Users\user\Documents\repos\hypotez\src\suppliers\__init__.py:24
#       1 """! @ru_brief Модуль `suppliers` oтвечает за все манипуляции с товаром относительно поставщика.
#       2
#       3 @ru_details
#    (...)
#      18  @file
#      19 """
#      21 # -*- coding: utf-8 -*-
#      22 #! /usr/share/projects/hypotez/venv/scripts python
# ---> 24 from .supplier import Supplier
#
# File c:\Users\user\Documents\repos\hypotez\src\suppliers\supplier.py:41
#      39 from io_interface import j_loads, j_dumps
#      40 from helpers import logger,  logs_and_errors_decorator,  jprint, pprint
# ---> 41 from webdriver import Driver
#      42 from scenarios import executor
#      43 # ----------------------------------
#
# File c:\Users\user\Documents\repos\hypotez\src\webdriver\__init__.py:17
#       1 """! @ru_brief Вебдрайвер.
#       2 @ru_details Я объединил в класс `Driver` все, что взаимодействует по протоколу `HTTP`:
#       3 - `selenium`
#    (...)
#      11   - .Driver
#      12 """
#      14 # -*- coding: utf-8 -*-
#      15 #! /usr/share/projects/hypotez/venv/scripts python
# ---> 17 from .Driver import Driver
#
# File c:\Users\user\Documents\repos\hypotez\src\webdriver\Driver.py:201
#     199 from helpers import  logger, jprint
#     200 from tools import StringFormatter as SF
# --> 201 from . import execute_locator, js
#     202 # -------------------------------
#     203
#     204     #####################################################################
#    (...)
#     207     #                                                                   #
#     208     #####################################################################
#     211 if gs.webdriver == 'firefox':
#
# File c:\Users\user\Documents\repos\hypotez\src\webdriver\execute_locator.py:52
#      50 from io_interface import j_loads, j_dumps
#      51 from tools.string_formatter import StringFormatter as SF
# ---> 52 from product import Product
#      53 # ------------------------------
#      55 def execute_locator(driver: Driver, locator: dict, keys: Union[Keys, None] = None) -> Union[list, dict, None, str]:
#
# File ~\Documents\repos\hypotez\src\product\product.py:34
#      32 from helpers import jprint, pprint
#      33 from io_interface import j_loads, j_dumps
# ---> 34 from .product_fields import ProductFields
#      35 from prestashop import Product as PrestaProduct, Category as PrestaCategory
#      36 from src.prestashop.supplier import Supplier as PrestaSupplier
#
# ImportError: attempted relative import with no known parent package
