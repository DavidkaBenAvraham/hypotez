# %%
import header

# %%
from global_settings import gs
# Out:
# Traceback (most recent call last):
#
#   File ~\Documents\repos\hypotez\venv\Lib\site-packages\IPython\core\interactiveshell.py:3508 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[2], line 1
#     from global_settings import gs
#
#   File ~\Documents\repos\hypotez\src\gs\__init__.py:37
#     from .global_settings import gs, dir_root
#
#   File ~\Documents\repos\hypotez\src\gs\gs.py:132
#     \classmethod
#      ^
# SyntaxError: unexpected character after line continuation character
