# %%
import sys
import os
path = os.getcwd()[:os.getcwd().rfind(r'\hypotez')]
sys.path.append(path)  # Добавляю корневую папку в sys.path
from hypotez import Driver
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\onela\OneDrive\REPOS\DavidkaBenAvraham\hypotez\venv\Lib\site-packages\IPython\core\interactiveshell.py:3508 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[3], line 5
#     from hypotez import Driver
#
#   File c:\Users\onela\OneDrive\REPOS\DavidkaBenAvraham\hypotez\__init__.py:13
#     >>>>>>> 01d63fa62eefbcbe743bb539848271276cde0666
#             ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
