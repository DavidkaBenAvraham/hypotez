# %%
# %reload_ext jupyter_ai
# %env OPENAI_API_KEY=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
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_line_magic('reload_ext', 'jupyter_ai')
#       2 get_ipython().run_line_magic('env', 'OPENAI_API_KEY=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')
#
# File C:\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2369, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2367     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2368 with self.builtin_trap:
# -> 2369     result = fn(*args, **kwargs)
#    2371 # The code below prevents the output from being displayed
#    2372 # when using magics with decodator @output_can_be_silenced
#    2373 # when the last Python token in the expression is a ';'.
#    2374 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
# %%ai chatgpt --format text
# как жить дальше
# Out:
# Жить дальше можно разными способами, в зависимости от обстоятельств, поставленных целей и личных предпочтений. Однако, вот несколько общих советов, которые, на мой взгляд, помогут вам продолжать жить и развиваться:
#
# 1. Не зацикливайтесь на прошлом и не бойтесь будущего. Живите настоящим и стройте свою жизнь сегодня.
#
# 2. Более часто улыбайтесь и делайте добрые дела. Это не только поднимает настроение, но и помогает укрепить отношения с окружающими.
#
# 3. Не пренебрегайте своим здоровьем: занимайтесь спортом, правильно питайтесь и следите за сном.
#
# 4. Развивайте свои увлечения и интересы, находите время на путешествия и новые впечатления.
#
# 5. Ставьте себе цели и не бойтесь рисковать, что позволит вам продвигаться вперед и достигать успеха.
#
# 6. Окружайтесь любимыми и близкими людьми - они всегда поддержат, дадут совет и помощь в трудную минуту.
#
# ...

# %%
# %%ai chatgpt --format text
# Furniture categories by place in office from entrance
# Out:
# 1. Reception area furniture - This includes reception desks, chairs, and sofas for clients and visitors to wait in.
# 2. Conference room furniture - This includes conference tables, chairs, and presentation equipment for meetings with clients, employees, or other companies.
# 3. Office seating - This includes chairs for workstations, executive offices, and conference rooms.
# 4. Cubicle furniture - This includes workstations, filing cabinets, and office dividers for employees in open office spaces.
# 5. Executive office furniture - This includes desks, chairs, bookcases, and other furniture for high-level executives and managers.
# 6. Storage furniture - This includes filing cabinets, bookcases, and shelves for storing files, books, and other office supplies.
# 7. Break room furniture - This includes tables, chairs, and lounge furniture for employees to take breaks and eat lunch.
# ...

# %%
pages_category = {
    "Name":None,
    "Description":None,
    "Meta title":None,
    "Meta description":None,
    "Meta keywords":None,
    "Friendly URL":None
    }

# %%
company_articles = dict(pages_categories)

# %%
article = {
    "Title":None,
    "SEO preview":None,
    "Meta title":None,
    "Meta description":None,
    "Meta keywords":None,
    "Friendly URL":None,
    "Page content":None,
    
}

# %%
furniture_is_our_specialty = {"en":dict(article),"he":dict(article),"ru":dict(article)}

# %%
# %%ai chatgpt --format html
# Write introduction article for furniture company
# Write in russian
#
# Keywords for article:
#     "мебельная фабрика","персональный дизайн мебели","изготовление на заказ",
#     "аккуратная перевозка мебели","сборка","ремонт","обновление","доставка","перевозка",
#     "гарантия","опыт","знания","умения","навыки","наша профессия"
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# 	<title>Мебельная фабрика - персональный дизайн мебели на заказ</title>
# </head>
# <body>
# 	<h1>Мебельная фабрика - персональный дизайн мебели на заказ</h1>
# 	<p>Наша мебельная фабрика предоставляет услуги по изготовлению мебели на заказ. У нас есть множество возможностей для создания эксклюзивного дизайна, подходящего именно вам. С помощью наших профессионалов вы можете оформить вашу мебель по вашему вкусу.</p>
# 	<p>Мы гарантируем аккуратную перевозку мебели к вам домой и сборку на месте. Если мебель нуждается в ремонте или обновлении, мы также можем оказать профессиональную помощь в этом вопросе. Мы также предоставляем услуги по доставке и перевозке вашей мебели.</p>
# 	<p>Наша профессия - это не только опыт, знания и умения, но и любовь к красивой и функциональной мебели. Мы уделяем особое внимание каждому деталю и всегда стремимся удовлетворить все ваши потребности. Вы можете полностью доверить дом нашей мебельной фабрике.</p>
# ...

# %%
# %%ai chatgpt --format text
# в твоем тексте много раз повторяется словосочетание "мебельная фабрика". Разбавь такими словами как "фирма","компания"
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# 	<title>Мебельная компания - персональный дизайн мебели на заказ</title>
# </head>
# <body>
# 	<h1>Мебельная компания - персональный дизайн мебели на заказ</h1>
# 	<p>Наша мебельная фирма предоставляет услуги по изготовлению мебели на заказ. У нас есть множество возможностей для создания эксклюзивного дизайна, подходящего именно вам. С помощью наших профессионалов вы можете оформить вашу мебель по вашему вкусу.</p>
# 	<p>Мы гарантируем аккуратную перевозку мебели к вам домой и сборку на месте. Если мебель нуждается в ремонте или обновлении, мы также можем оказать профессиональную помощь в этом вопросе. Мы также предоставляем услуги по доставке и перевозке вашей мебели.</p>
# 	<p>Наша профессия - это не только опыт, знания и умения, но и любовь к красивой и функциональной мебели. Мы уделяем особое внимание каждому деталю и всегда стремимся удовлетворить все ваши потребности. Вы можете полностью доверять дом нашей мебельной компании.</p>
# ...

# %%
# %%ai chatgpt --format text
# к уже имеющимся добавь ключевые слова: "фирма","компания"
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# 	<title>Мебельная фирма - персональный дизайн мебели на заказ</title>
# </head>
# <body>
# 	<h1>Мебельная фирма - персональный дизайн мебели на заказ</h1>
# 	<p>Наша мебельная компания предоставляет услуги по изготовлению мебели на заказ. У нас есть множество возможностей для создания эксклюзивного дизайна, подходящего именно вам. С помощью наших профессионалов вы можете оформить вашу мебель по вашему вкусу.</p>
# 	<p>Мы гарантируем аккуратную перевозку мебели к вам домой и сборку на месте. Если мебель нуждается в ремонте или обновлении, мы также можем оказать профессиональную помощь в этом вопросе. Мы также предоставляем услуги по доставке и перевозке вашей мебели.</p>
# ...

# %%
# %%ai chatgpt --format text
# Сделай болше текста в абзацах
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# 	<title>Мебельная фирма - персональный дизайн мебели на заказ</title>
# </head>
# <body>
# 	<h1>Мебельная фирма - персональный дизайн мебели на заказ</h1>
# 	<p>Наша мебельная компания предоставляет услуги по изготовлению мебели на заказ. Мы знаем, что каждый клиент уникален, и потребности каждого человека различны. Именно поэтому мы предоставляем персональный подход к нашим клиентам и помогаем им создать мебель, которая отвечает их нуждам и вкусам.</p>
# 	<p>Мы с уверенностью можем сказать, что у нас есть множество возможностей для создания эксклюзивного дизайна, который будет именно под интерьер. Наши профессиональные дизайнеры и мастера помогут вам оформить вашу мебель так, чтобы она не только была красивой и эстетичной, но и функциональной и удобной в использовании. Наша цель - создать мебель, которая удовлетворит все ваши потребности и станет идеальным дополнением к вашему дому.</p>
# ...

# %%
# %%ai chatgpt --format text
# переведи на иврит
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# 	<title>חברת הריהוט - העיצוב האישי שלך לריהוט על פי הזמנה</title>
# </head>
# <body dir="rtl">
# 	<h1>חברת הריהוט - העיצוב האישי שלך לריהוט על פי הזמנה</h1>
# 	<p>חברת הריהוט שלנו מציעה שירותים לייצור ריהוט על פי הזמנה. אנחנו יודעים שכל לקוח הוא יחודי ושצרכי כל אדם שונים, ולכן אנחנו מציעים שירות אישי ונעזור לכם ליצור ריהוט שיתאים לצרכים ולטעמים שלכם.</p>
# 	<p>אנחנו בטוחים שיש לנו הרבה אפשרויות ליצירת עיצוב מיוחד, בהתאם למה שמתאים לכם על הפנים. המעצבים והמומחים הטכניים שלנו יעזרו לכם לעצב את הריהוט שלכם בדיוק כפי שאתם רוצים, כך שהריהוט שלכם לא יהיה רק יפה ואסתטי, אלא גם פונקציונלי ונוח לשימוש. המטרה שלנו היא ליצור ריהוט שיעמוד בכל הצרכים שלכם ויהפוך לתוספת מושלמת לבית שלכם.</p>
# 	<p>אנחנו מבטיחים הובלה והרכבה - נכונים ומקצועיים - לכל הריהוט שנמצא אצלכם. אם הריהוט שלכם זקוק לתיקון או לשדרוג, נוכל לסייע בכך גם. אנחנו מספקים גם שירותי משלוח והובלה כדי להבטיח שהריהוט שלכם נמצא במקום בזמן הנכון ובמצב הנדרש.</p>
# ...

# %%
# %%ai chatgpt --format text
# продолжай с третьего параграфа
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 get_ipython().run_cell_magic('ai', 'chatgpt --format text', 'продолжай с третьего параграфа\n')
#
# File ~\OneDrive\REPOS\DavidkaBenAvraham\hypotez\venv\Lib\site-packages\IPython\core\interactiveshell.py:2478, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2476 with self.builtin_trap:
#    2477     args = (magic_arg_s, cell)
# -> 2478     result = fn(*args, **kwargs)
#    2480 # The code below prevents the output from being displayed
#    2481 # when using magics with decodator @output_can_be_silenced
#    2482 # when the last Python token in the expression is a ';'.
#    2483 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\OneDrive\REPOS\DavidkaBenAvraham\hypotez\venv\Lib\site-packages\jupyter_ai_magics\magics.py:348, in AiMagics.ai(self, line, cell)
# ...

# %%
text1 = f"""
Welcome to Our Furniture Company!
We are thrilled to introduce you to our top-quality furniture offerings! Our furniture company has been dedicated to crafting beautiful and durable pieces for homes and businesses alike for years. We specialize in a variety of styles, from timeless classics to contemporary designs, and we pride ourselves in using only the finest materials and employing skilled craftsmanship in every piece we create.

Whether you are looking for a new sofa or a complete bedroom set, we have a wide range of options to choose from. Our collection includes everything from elegant dining room tables and chairs to cozy armchairs and stylish bookshelves. Our furniture lets you create the perfect ambiance for your space while ensuring you have a functional and comfortable place to relax and unwind.

At our furniture company, we believe that quality and affordability go hand in hand. We are committed to keeping our prices competitive, and we offer a variety of discounts throughout the year, so you can always find the perfect piece without breaking the bank. We also offer fast and reliable delivery, so you can enjoy your new furniture in no time.

We invite you to browse our website and explore our collection of furniture today. We are confident that you will find something that speaks to your style and enhances the functionality and beauty of your space. We are passionate about furniture, and we know that our passion shows in the quality of our products. Thank you for considering us for all your furniture needs!

"""

# %%
# %%ai chatgpt --format html
# repeat your answer in hebrew
# Out:
# <div>
#   <h1>ברוכים הבאים לחברת הריהוט שלנו!</h1>
#   <p>
#      אנחנו שמחים להציג לכם את המבחר האיכותי שלנו של רהיטים! חברת הריהוט שלנו הייתה מחויבת לייצור פריטי ריהוט יפים ועמידים לבתים ולעסקים כבר שנים. אנחנו מתמחים במגוון סגנונות, מקלסיקות בלתי עתיקות עד עיצובים עכשוויים, ואנחנו גאים בשימוש רק בחומרי הגלם הטובים ביותר ובהוצאת מקצועיות כל פריט אנחנו יוצרים.
#   </p>
#   <p>
#      בין אם אתם מחפשים ספה חדשה או ערכת שינה מלאה, יש לנו מגוון רחב של אפשרויות לבחירה. האוסף שלנו כולל הכול, משולחני אוכל אלגנטיים וכסאות לכיש בטוח וסטיילי למדפי ספרים נעימים ומעוצבים. הריהוט שלנו מאפשר לכם ליצור אווירה המושלמת בחלל שלכם תוך הבטחת פונקציונאליות ומקום נוח כדי להירגע ולהתרפא.
#   </p>
#   <p>
# ...
