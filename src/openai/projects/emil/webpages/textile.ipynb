# %%
# %reload_ext jupyter_ai
# %env OPENAI_API_KEY=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
# Out:
# env: OPENAI_API_KEY=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

# %%
# %%ai chatgpt --format text
# Write introduction article for home design textile shop
# Out:
# <html>
# <head>
# <title>Introduction to Our Home Design Textile Shop</title>
# </head>
# <body>
# <h1>Welcome to Our Home Design Textile Shop</h1>
# <p>We are delighted to invite you to our home design textile shop, where style meets functionality. Our shop offers a vast collection of high-quality fabrics that can help you transform your home's look and feel. </p>
# <p>Our collection includes a wide range of fabrics for every interior design need, including cushions, curtains, bedspreads, towels, tablecloths, and upholstery fabrics in different colors, patterns, and designs. Our collection is carefully curated to bring you the latest trends while maintaining a good balance of classic pieces that never go out of style.</p>
# ...

# %%
# %%ai chatgpt --format text
# Write 5 slogans for home design textile shop
# Out:
# <html>
# <head>
# <title>Slogans for Our Home Design Textile Shop</title>
# </head>
# <body>
# <h1>Slogans for Our Home Design Textile Shop</h1>
# <ul>
# <li><strong><em>Add a Touch of Elegance to Your Home with Our Premium Fabrics.</em></strong></li>
#
# <li><strong><em>Your Destination for Chic and Comfortable Home Textiles.</em></strong></li>
#
# <li><strong><em>Revamp Your Space with Our Trendy and Affordable Textiles.</em></strong></li>
#
# <li><strong><em>Experience the Comfort and Beauty of Our Textiles.</em></strong></li>
#
# <li><strong><em>Enhancing Your Home, One Fabric at a Time.</em></strong></li>
# </ul>
# </body>
# </html>

# %%
# %%ai chatgpt --format html
# more
# Out:
# <html>
# <head>
# <title>More Slogans for Our Textile Shop</title>
# </head>
# <body>
# <h1>More Slogans for Our Textile Shop</h1>
# <ul>
# <li><strong><em>Unleash Your Creativity with Our Fabrics.</em></strong></li>
#
# <li><strong><em>Fabrics that Inspire, Designs that Impress.</em></strong></li>
#
# <li><strong><em>Your One-Stop Shop for All Your Sewing Needs.</em></strong></li>
#
# <li><strong><em>Experience the Beauty of High-Quality Fabrics.</em></strong></li>
#
# <li><strong><em>Quality Fabrics. Quality Results.</em></strong></li>
# </ul>
# </body>
# </html>

# %%
# %%ai chatgpt --format text
# description for  about home design textile shop in 170 words
# Out:
# <html>
# <head>
# <title>Description of Our Textile Shop</title>
# </head>
# <body>
# <h1>Description of Our Textile Shop</h1>
# <p>We are a premier textile shop that offers a wide range of high-quality fabrics to meet all your sewing needs. From cotton to silk, wool to linen, and polyester to specialty fabrics, we have something to suit every project and taste. </p>
# <p>Our collection includes a vast selection of colors, patterns, and styles, perfect for crafting unique garments, home decor, and accessories. We take pride in our commitment to excellent customer service, providing a personalized shopping experience to our clients. Our knowledgeable staff is always on hand to offer advice and guidance, ensuring that you will find the perfect fabric for your project.</p>
# ...

# %%
# %%ai chatgpt --format text
# keywords for home textile shop in one line with commas separator
# Out:
# home textile shop, cushions, curtains, bedspreads, towels, tablecloths, home decor, upholstery fabrics, stylish designs, affordable prices

# %%
# %%ai chatgpt --format html
# description for searh engeene

# %%
# %%ai chatgpt --format text
# תכתוב מעמר לחנות שמוכרת טקסטיל לעיצוב בית
# Out:
# כותרת: ברוכים הבאים לחנות הטקסטיל לעיצוב הבית שלנו!
#
# שלום לכולם,
#
# אנו מזמינים אתכם לגלות את חנות הטקסטיל לעיצוב הבית שלנו! אנו מתמחים במכירת בדים איכותיים ואסטתיים ללא פשרות, המתאימים לכל רעיון ותקציב לעיצוב הבית שלכם.
#
# בחנות שלנו, תוכלו למצוא מבחר רחב של בדים על מנת ליצור חוויית עיצוב מושלמת לבית שלכם. לדוגמה, אנו מציעים תחפושות, מפות מטבח, ונדנדות עם הבדים הכי יפים והכי עמידים בשוק כי רציונליות זה חשוב לנו כמו רק אסתטיקה. חשוב לנו להציע ללקוחותינו בדים איכותיים ביותר, כך שהם לא יצטרכו להתאכזב ולחפש מחדש לאחר כמה חודשים רק בגלל שהבדים לא היו עמידים לשימוש היום יום.
#
# אנו מאמינים כי הפרטים הקטנים הם החיוניים ביותר כשמדובר בעיצוב פנים. לכן, חשוב לנו לספק ללקוחותינו חוויית קניות אישית שלא תשכחו ממנה. הצוות הייחודי שלנו מורכב ממתן אספקה מקצועי וחברותי שיוכלו לסייע לכם בכל מה שתצטרכו, בכל שאלה או רעיון שתצטרכו לחשוב עליו.
#
# ...

# %%
# %reload_ext jupyter_ai
# %env OPENAI_API_KEY=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
# Out:
# env: OPENAI_API_KEY=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

# %%
# %%ai chatgpt --format text
# תכתוב תיאר למנעי חיפוש  - חנות שמוכרת טקסטיל לעיצוב בית
# Out:
# החנות המדהימה הזו מציעה ללקוחותיה את האופציות הכי מדהימות לעיצוב הבית. כאן תוכלו למצוא מגוון עצום של טקסטיל לעיצוב הבית, החל מבדי גליל לצעיף וכריות מפנקות עד לפעמוני מיטה ושמיכות מפנקות. החנות מאפשרת לכל מי שמחפש שטיפה של שינוי ללבוש את הבית בצורה שישרת את העין ותעשה לו טוב. תוכלו למצוא פה בדי איכות מעולה המתאימים לכל חדרי הבית - חדרי השינה, סלון, חדרי שרותים ואף לדמיין את עצמכם מכנסים למטבח תוך כדי בחירת ריפודים נפלאים לכסאות האוכל. המוצרים המצוינים האלו יגרמו לכל מי שייכנס לבית שלכם להתאהב בו ולהפוך אותו למקום חמים ונעים לבילוי.
