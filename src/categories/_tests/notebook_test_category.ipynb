# %%
# -*- coding: utf-8 -*-
#! /usr/share/projects/hypotez/venv/scripts python
import header
from header import jprint, pprint, gs
from src.categories import  Category

# %% [markdown]
# ## Соглашения
# c = Category()

# %%
c = Category()

# %%
pprint(c.categories_tree_from_template_files)
# Out:
# {'11036 FURNITURE AND HOME ACCESSORIES': OrderedDict([('11044',
#                                                        'LIVING SPACE '
#                                                        'FURNITURE'),
#                                                       ('11045',
#                                                        'WORK SPACE '
#                                                        'FURNITURE')]),
#  '11036 SPACE HOME AND INTERIOR': OrderedDict([('ROOT',
#                                                 OrderedDict([('11036',
#                                                               'HOME AND '
#                                                               'INTERIOR')])),
#                                                ('11037 FURNITURE',
#                                                 OrderedDict([('template',
#                                                               OrderedDict([('11036 '
#                                                                             'SPACE '
#                                                                             'HOME '
#                                                                             'AND '
#                                                                             'INTERIOR',
#                                                                             'ROOT')])),
#                                                              ('11037',
#                                                               'FURNITURE')])),
#                                                ('11039 CARPETS',
#                                                 OrderedDict([('template',
#                                                               OrderedDict([('11036 '
#                                                                             'SPACE '
#                                                                             'HOME '
#                                                                             'AND '
#                                                                             'INTERIOR',
#                                                                             'ROOT')])),
#                                                              ('11039',
#                                                               'FURNITURE')])),
#                                                ('11040 MATRESSESS',
#                                                 OrderedDict([('template',
#                                                               OrderedDict([('11036 '
#                                                                             'SPACE '
#                                                                             'HOME '
#                                                                             'AND '
#                                                                             'INTERIOR',
#                                                                             'ROOT')])),
#                                                              ('11040',
#                                                               'MATRESSESS')])),
#                                                ('11041 TEXTILE',
#                                                 OrderedDict([('template',
#                                                               OrderedDict([('11036 '
#                                                                             'SPACE '
#                                                                             'HOME '
#                                                                             'AND '
#                                                                             'INTERIOR',
#                                                                             'ROOT')])),
#                                                              ('11041',
#                                                               'TEXTILE')])),
#                                                ('11042 HOME ACCESSORIES',
#                                                 OrderedDict([('template',
#                                                               OrderedDict([('11036 '
#                                                                             'SPACE '
#                                                                             'HOME '
#                                                                             'AND '
#                                                                             'INTERIOR',
#                                                                             'ROOT')])),
#                                                              ('11042',
#                                                               'HOME '
#                                                               'ACCESSORIES')])),
#                                                ('11206 ART DEKO',
#                                                 OrderedDict([('template',
#                                                               OrderedDict([('11036 '
#                                                                             'SPACE '
#                                                                             'HOME '
#                                                                             'AND '
#                                                                             'INTERIOR',
#                                                                             'ROOT')])),
#                                                              ('11206',
#                                                               'ART DEKO')])),
#                                                ('11208 Light and Electrical',
#                                                 OrderedDict([('template',
#                                                               OrderedDict([('11036 '
#                                                                             'SPACE '
#                                                                             'HOME '
#                                                                             'AND '
#                                                                             'INTERIOR',
#                                                                             'ROOT')])),
#                                                              ('11208',
#                                                               'Light and '
#                                                               'Electrical')])),
#                                                ('11223 Home appliances',
#                                                 OrderedDict([('template',
#                                                               OrderedDict([('11036 '
#                                                                             'SPACE '
#                                                                             'HOME '
#                                                                             'AND '
#                                                                             'INTERIOR',
#                                                                             'ROOT')])),
#                                                              ('11223',
#                                                               'Home '
#                                                               'appliances')]))]),
#  '11037 FURNITURE': OrderedDict([('ROOT',
#                                   OrderedDict([('template',
#                                                 OrderedDict([('11036 SPACE '
#                                                               'HOME AND '
#                                                               'INTERIOR',
#                                                               '11037 '
#                                                               'FURNITURE')]))])),
#                                  ('LIVING SPACE FURNITURE',
#                                   OrderedDict([('template',
#                                                 OrderedDict([('11037 FURNITURE',
#                                                               'ROOT')])),
#                                                ('11044',
#                                                 'LIVING SPACE FURNITURE')])),
#                                  ('WORK SPACE FURNITURE',
#                                   OrderedDict([('template',
#                                                 OrderedDict([('11037 FURNITURE',
#                                                               'ROOT')])),
#                                                ('11045',
#                                                 'WORK SPACE FURNITURE')]))]),
#  '11042 HOME ACCESSORIES': OrderedDict([('ROOT',
#                                          OrderedDict([('template',
#                                                        OrderedDict([('11036 '
#                                                                      'SPACE '
#                                                                      'HOME AND '
#                                                                      'INTERIOR',
#                                                                      '11042 '
#                                                                      'HOME '
#                                                                      'ACCESSORIES')]))])),
#                                         ('11208 Decorative pillows and cushion '
#                                          'covers',
#                                          OrderedDict([('template',
#                                                        OrderedDict([('11042 '
#                                                                      'HOME '
#                                                                      'ACCESSORIES',
#                                                                      'ROOT')])),
#                                                       ('11208',
#                                                        'Decorative pillows and '
#                                                        'cushion covers')]))]),
#  '11206 ART DEKO': OrderedDict([('ROOT',
#                                  OrderedDict([('template',
#                                                OrderedDict([('11036 SPACE HOME '
#                                                              'AND INTERIOR',
#                                                              '11206 ART '
#                                                              'DEKO')]))])),
#                                 ('11209 MURANO GLASS',
#                                  OrderedDict([('template',
#                                                OrderedDict([('11206 ART DEKO',
#                                                              'ROOT')])),
#                                               ('11209', 'MURANO GLASS')]))]),
#  '3198 CONSUMER ELECTRONICS': OrderedDict([('3198 CONSUMER ELECTRONICS',
#                                             OrderedDict([('3198',
#                                                           'CONSUMER '
#                                                           'ELECTRONICS')])),
#                                            ('LAPTOPS',
#                                             OrderedDict([('3225', 'LAPTOPS'),
#                                                          ('3202',
#                                                           'Computers, '
#                                                           'Consoles, Gaming '
#                                                           'Devices'),
#                                                          ('template',
#                                                           OrderedDict([('3198 '
#                                                                         'CONSUMER '
#                                                                         'ELECTRONICS',
#                                                                         '3198 '
#                                                                         'CONSUMER '
#                                                                         'ELECTRONICS')]))])),
#                                            ('SMART WATCHES',
#                                             OrderedDict([('6472',
#                                                           'Smartwatches'),
#                                                          ('3433',
#                                                           'Computers, '
#                                                           'Consoles, Gaming '
#                                                           'Devices'),
#                                                          ('template',
#                                                           OrderedDict([('3198 '
#                                                                         'CONSUMER '
#                                                                         'ELECTRONICS',
#                                                                         '3198 '
#                                                                         'CONSUMER '
#                                                                         'ELECTRONICS')]))])),
#                                            ('TV AND AUDIO',
#                                             OrderedDict([('3437',
#                                                           'TV AND AUDIO')])),
#                                            ('TABLETS',
#                                             OrderedDict([('9449',
#                                                           'Tablets and Readers '
#                                                           'in SMARTDEVICES'),
#                                                          ('3227',
#                                                           'Tablets in '
#                                                           'Computers, '
#                                                           'Consoles, Gaming'),
#                                                          ('3433',
#                                                           'Cell Phones, Smart '
#                                                           'Devices'),
#                                                          ('3202',
#                                                           'Computers, '
#                                                           'Consoles, Gaming '
#                                                           'Devices'),
#                                                          ('template',
#                                                           OrderedDict([('3198 '
#                                                                         'CONSUMER '
#                                                                         'ELECTRONICS',
#                                                                         '3198 '
#                                                                         'CONSUMER '
#                                                                         'ELECTRONICS')]))])),
#                                            ('AIO',
#                                             OrderedDict([('3371', 'AIO'),
#                                                          ('3202',
#                                                           'Computers, '
#                                                           'Consoles, Gaming '
#                                                           'Devices'),
#                                                          ('template',
#                                                           OrderedDict([('3198 '
#                                                                         'CONSUMER '
#                                                                         'ELECTRONICS',
#                                                                         '3198 '
#                                                                         'CONSUMER '
#                                                                         'ELECTRONICS')]))])),
#                                            ('HEADPHONES',
#                                             OrderedDict([('3454', 'HEADPHONES'),
#                                                          ('3436',
#                                                           '3436 SPEAKERS & '
#                                                           'AUDIO'),
#                                                          ('3198',
#                                                           'CONSUMER '
#                                                           'ELECTRONICS'),
#                                                          ('3437',
#                                                           'TV AND AUDIO'),
#                                                          ('3997',
#                                                           'HEADPHONES')])),
#                                            ('PC MONITORS',
#                                             OrderedDict([('3448',
#                                                           'PC Monitors in '
#                                                           'Computers, '
#                                                           'Consoles, Gaming-0'),
#                                                          ('3202',
#                                                           'Computers, '
#                                                           'Consoles, Gaming'),
#                                                          ('3198',
#                                                           'CONSUMER '
#                                                           'ELECTRONICS'),
#                                                          ('3437',
#                                                           'TV AND AUDIO'),
#                                                          ('4000',
#                                                           'PC Monitors in TV '
#                                                           'AND AUDIO')])),
#                                            ('BATTERIES & POWER',
#                                             OrderedDict([('3343',
#                                                           'Batteries & Power '
#                                                           'Supplies'),
#                                                          ('3198',
#                                                           'CONSUMER '
#                                                           'ELECTRONICS'),
#                                                          ('3342',
#                                                           'BATTERIES AND POWER '
#                                                           'SUPPLY 3342')])),
#                                            ('SMARTPHONES',
#                                             OrderedDict([('6471',
#                                                           'SMARTPHONES BY '
#                                                           'BRAND'),
#                                                          ('3198',
#                                                           'CONSUMER '
#                                                           'ELECTRONICS'),
#                                                          ('3433',
#                                                           'computer,smartphone,gaming '
#                                                           'console,smart '
#                                                           'device')])),
#                                            ('DESKTOP COMPUTERS',
#                                             OrderedDict([('3224',
#                                                           'DESKTOP COMPUTERS'),
#                                                          ('3202',
#                                                           'Computers, '
#                                                           'Consoles, Gaming '
#                                                           'Devices'),
#                                                          ('template',
#                                                           OrderedDict([('3198 '
#                                                                         'CONSUMER '
#                                                                         'ELECTRONICS',
#                                                                         '3198 '
#                                                                         'CONSUMER '
#                                                                         'ELECTRONICS')]))]))]),
#  '3229 DESKTOP COMPUTER HARDWARE': OrderedDict([('ROOT',
#                                                  OrderedDict([('3198',
#                                                                'CONSUMER '
#                                                                'ELECTRONICS'),
#                                                               ('3202',
#                                                                'Computers, '
#                                                                'Consoles, '
#                                                                'Gaming '
#                                                                'Devices'),
#                                                               ('3229',
#                                                                'desktop '
#                                                                'computer '
#                                                                'hardware')])),
#                                                 ('MOTHERBOARDS',
#                                                  OrderedDict([('template',
#                                                                OrderedDict([('3229 '
#                                                                              'DESKTOP '
#                                                                              'COMPUTER '
#                                                                              'HARDWARE',
#                                                                              'ROOT')])),
#                                                               ('3449',
#                                                                'Motherboards')])),
#                                                 ('CPU',
#                                                  OrderedDict([('template',
#                                                                OrderedDict([('3229 '
#                                                                              'DESKTOP '
#                                                                              'COMPUTER '
#                                                                              'HARDWARE',
#                                                                              'ROOT')])),
#                                                               ('4767',
#                                                                'CPU')])),
#                                                 ('RAM',
#                                                  OrderedDict([('template',
#                                                                OrderedDict([('3229 '
#                                                                              'DESKTOP '
#                                                                              'COMPUTER '
#                                                                              'HARDWARE',
#                                                                              'ROOT')])),
#                                                               ('4768',
#                                                                'RAM')])),
#                                                 ('VIDEOCARDS',
#                                                  OrderedDict([('template',
#                                                                OrderedDict([('3229 '
#                                                                              'DESKTOP '
#                                                                              'COMPUTER '
#                                                                              'HARDWARE',
#                                                                              'ROOT')])),
#                                                               ('9002',
#                                                                'VIDEOCARDS')])),
#                                                 ('PSU',
#                                                  OrderedDict([('template',
#                                                                OrderedDict([('3229 '
#                                                                              'DESKTOP '
#                                                                              'COMPUTER '
#                                                                              'HARDWARE',
#                                                                              'ROOT')])),
#                                                               ('4769',
#                                                                'PSU')])),
#                                                 ('COMPUTER CASES',
#                                                  OrderedDict([('template',
#                                                                OrderedDict([('3229 '
#                                                                              'DESKTOP '
#                                                                              'COMPUTER '
#                                                                              'HARDWARE',
#                                                                              'ROOT')])),
#                                                               ('4770',
#                                                                'computer '
#                                                                'cases')])),
#                                                 ('COMPUTER STORAGE',
#                                                  OrderedDict([('7498',
#                                                                'Storage'),
#                                                               ('template',
#                                                                OrderedDict([('desktop_hardware',
#                                                                              'DESKTOP '
#                                                                              'COMPUTER '
#                                                                              'HARDWARE')]))])),
#                                                 ('KEYBOARD AND MICE',
#                                                  OrderedDict([('template',
#                                                                OrderedDict([('3229 '
#                                                                              'DESKTOP '
#                                                                              'COMPUTER '
#                                                                              'HARDWARE',
#                                                                              'ROOT')])),
#                                                               ('7499',
#                                                                'KeyBoard and '
#                                                                'mice')])),
#                                                 ('NETWORK',
#                                                  OrderedDict([('template',
#                                                                OrderedDict([('3229 '
#                                                                              'DESKTOP '
#                                                                              'COMPUTER '
#                                                                              'HARDWARE',
#                                                                              'ROOT')])),
#                                                               ('3449',
#                                                                'Motherboards')])),
#                                                 ('UPS',
#                                                  OrderedDict([('template',
#                                                                OrderedDict([('3229 '
#                                                                              'DESKTOP '
#                                                                              'COMPUTER '
#                                                                              'HARDWARE',
#                                                                              'ROOT')])),
#                                                               ('3449',
#                                                                'Motherboards')])),
#                                                 ('SOUND',
#                                                  OrderedDict([('template',
#                                                                OrderedDict([('3229 '
#                                                                              'DESKTOP '
#                                                                              'COMPUTER '
#                                                                              'HARDWARE',
#                                                                              'ROOT')])),
#                                                               ('7503',
#                                                                'Sound')])),
#                                                 ('PC MONITORS',
#                                                  OrderedDict([('template',
#                                                                OrderedDict([('3229 '
#                                                                              'DESKTOP '
#                                                                              'COMPUTER '
#                                                                              'HARDWARE',
#                                                                              'ROOT')])),
#                                                               ('7504',
#                                                                'PC '
#                                                                'MONITORS')])),
#                                                 ('GAMING ACCESSORIES',
#                                                  OrderedDict([('template',
#                                                                OrderedDict([('3229 '
#                                                                              'DESKTOP '
#                                                                              'COMPUTER '
#                                                                              'HARDWARE',
#                                                                              'ROOT')])),
#                                                               ('7505',
#                                                                'GAMING '
#                                                                'ACCESSORIES')])),
#                                                 ('PRINTERS AND SCANNERS',
#                                                  OrderedDict([('template',
#                                                                OrderedDict([('3229 '
#                                                                              'DESKTOP '
#                                                                              'COMPUTER '
#                                                                              'HARDWARE',
#                                                                              'ROOT')])),
#                                                               ('7506',
#                                                                'PRINTERS AND '
#                                                                'SCANNERS')])),
#                                                 ('NAS',
#                                                  OrderedDict([('template',
#                                                                OrderedDict([('3229 '
#                                                                              'DESKTOP '
#                                                                              'COMPUTER '
#                                                                              'HARDWARE',
#                                                                              'ROOT')])),
#                                                               ('11145',
#                                                                'NAS')])),
#                                                 ('COOLING',
#                                                  OrderedDict([('template',
#                                                                OrderedDict([('3229 '
#                                                                              'DESKTOP '
#                                                                              'COMPUTER '
#                                                                              'HARDWARE',
#                                                                              'ROOT')])),
#                                                               ('9252',
#                                                                'COOLING')])),
#                                                 ('UNSORTED',
#                                                  OrderedDict([('template',
#                                                                OrderedDict([('3229 '
#                                                                              'DESKTOP '
#                                                                              'COMPUTER '
#                                                                              'HARDWARE',
#                                                                              'ROOT')])),
#                                                               ('9578',
#                                                                'UNSORTED')]))]),
#  '3439 SMARTHOME': OrderedDict([('SMARTHOME',
#                                  OrderedDict([('3198', 'CONSUMER ELECTRONICS'),
#                                               ('3433',
#                                                'computer,smartphone,gaming '
#                                                'console,smart device'),
#                                               ('6474', 'SMARTHOME')])),
#                                 ('SMARTCAMERA',
#                                  OrderedDict([('template',
#                                                OrderedDict([('SMARTHOME',
#                                                              '6474')])),
#                                               ('9583', 'Smart Cameras')]))]),
#  '4770 COMPUTER CASES': OrderedDict([('FULL TOWER',
#                                       OrderedDict([('7585', 'Full tower'),
#                                                    ('template',
#                                                     OrderedDict([('3229 '
#                                                                   'DESKTOP '
#                                                                   'COMPUTER '
#                                                                   'HARDWARE',
#                                                                   'COMPUTER '
#                                                                   'CASES')]))])),
#                                      ('MID TOWER',
#                                       OrderedDict([('7586', 'MID TOWER'),
#                                                    ('template',
#                                                     OrderedDict([('3229 '
#                                                                   'DESKTOP '
#                                                                   'COMPUTER '
#                                                                   'HARDWARE',
#                                                                   'COMPUTER '
#                                                                   'CASES')]))])),
#                                      ('MINI TOWER',
#                                       OrderedDict([('7587', 'Mini Tower'),
#                                                    ('template',
#                                                     OrderedDict([('3229 '
#                                                                   'DESKTOP '
#                                                                   'COMPUTER '
#                                                                   'HARDWARE',
#                                                                   'COMPUTER '
#                                                                   'CASES')]))])),
#                                      ('GAMING MID TOWER',
#                                       OrderedDict([('7588', 'Gaming MID TOWER'),
#                                                    ('template',
#                                                     OrderedDict([('3229 '
#                                                                   'DESKTOP '
#                                                                   'COMPUTER '
#                                                                   'HARDWARE',
#                                                                   'COMPUTER '
#                                                                   'CASES')]))])),
#                                      ('GAMING FULL TOWER',
#                                       OrderedDict([('7652',
#                                                     'Gaming Full Tower'),
#                                                    ('template',
#                                                     OrderedDict([('3229 '
#                                                                   'DESKTOP '
#                                                                   'COMPUTER '
#                                                                   'HARDWARE',
#                                                                   'COMPUTER '
#                                                                   'CASES')]))])),
#                                      ('ITX',
#                                       OrderedDict([('7590', 'ITX'),
#                                                    ('template',
#                                                     OrderedDict([('3229 '
#                                                                   'DESKTOP '
#                                                                   'COMPUTER '
#                                                                   'HARDWARE',
#                                                                   'COMPUTER '
#                                                                   'CASES')]))])),
#                                      ('MINI ITX',
#                                       OrderedDict([('7591', 'MINI ITX'),
#                                                    ('template',
#                                                     OrderedDict([('3229 '
#                                                                   'DESKTOP '
#                                                                   'COMPUTER '
#                                                                   'HARDWARE',
#                                                                   'COMPUTER '
#                                                                   'CASES')]))])),
#                                      ('CFF (Сompact Form Factor)',
#                                       OrderedDict([('7592',
#                                                     'CFF (Сompact Form '
#                                                     'Factor)'),
#                                                    ('template',
#                                                     OrderedDict([('3229 '
#                                                                   'DESKTOP '
#                                                                   'COMPUTER '
#                                                                   'HARDWARE',
#                                                                   'COMPUTER '
#                                                                   'CASES')]))])),
#                                      ('LFF (Low Profile Form Factor)',
#                                       OrderedDict([('7593',
#                                                     'LFF (Low Profile Form '
#                                                     'Factor)'),
#                                                    ('template',
#                                                     OrderedDict([('3229 '
#                                                                   'DESKTOP '
#                                                                   'COMPUTER '
#                                                                   'HARDWARE',
#                                                                   'COMPUTER '
#                                                                   'CASES')]))])),
#                                      ('SFF (Small Form Factor)',
#                                       OrderedDict([('7594',
#                                                     'SFF (Small Form Factor)'),
#                                                    ('template',
#                                                     OrderedDict([('3229 '
#                                                                   'DESKTOP '
#                                                                   'COMPUTER '
#                                                                   'HARDWARE',
#                                                                   'COMPUTER '
#                                                                   'CASES')]))])),
#                                      ('TFF (Thin Form Factor)',
#                                       OrderedDict([('7595',
#                                                     'SFF (Small Form Factor)'),
#                                                    ('template',
#                                                     OrderedDict([('3229 '
#                                                                   'DESKTOP '
#                                                                   'COMPUTER '
#                                                                   'HARDWARE',
#                                                                   'COMPUTER '
#                                                                   'CASES')]))])),
#                                      ('FLEX ATX',
#                                       OrderedDict([('7596', 'FlexATX'),
#                                                    ('template',
#                                                     OrderedDict([('3229 '
#                                                                   'DESKTOP '
#                                                                   'COMPUTER '
#                                                                   'HARDWARE',
#                                                                   'COMPUTER '
#                                                                   'CASES')]))])),
#                                      ('Mini PCI',
#                                       OrderedDict([('7597', 'Mini PCI'),
#                                                    ('template',
#                                                     OrderedDict([('3229 '
#                                                                   'DESKTOP '
#                                                                   'COMPUTER '
#                                                                   'HARDWARE',
#                                                                   'COMPUTER '
#                                                                   'CASES')]))])),
#                                      ('ATX',
#                                       OrderedDict([('7598', 'ATX'),
#                                                    ('template',
#                                                     OrderedDict([('3229 '
#                                                                   'DESKTOP '
#                                                                   'COMPUTER '
#                                                                   'HARDWARE',
#                                                                   'COMPUTER '
#                                                                   'CASES')]))])),
#                                      ('1U',
#                                       OrderedDict([('7599', '1U'),
#                                                    ('template',
#                                                     OrderedDict([('3229 '
#                                                                   'DESKTOP '
#                                                                   'COMPUTER '
#                                                                   'HARDWARE',
#                                                                   'COMPUTER '
#                                                                   'CASES')]))])),
#                                      ('2U',
#                                       OrderedDict([('7600', '2U'),
#                                                    ('template',
#                                                     OrderedDict([('3229 '
#                                                                   'DESKTOP '
#                                                                   'COMPUTER '
#                                                                   'HARDWARE',
#                                                                   'COMPUTER '
#                                                                   'CASES')]))])),
#                                      ('3U',
#                                       OrderedDict([('7601', '3U'),
#                                                    ('template',
#                                                     OrderedDict([('3229 '
#                                                                   'DESKTOP '
#                                                                   'COMPUTER '
#                                                                   'HARDWARE',
#                                                                   'COMPUTER '
#                                                                   'CASES')]))])),
#                                      ('4U',
#                                       OrderedDict([('7602', '4U'),
#                                                    ('template',
#                                                     OrderedDict([('3229 '
#                                                                   'DESKTOP '
#                                                                   'COMPUTER '
#                                                                   'HARDWARE',
#                                                                   'COMPUTER '
#                                                                   'CASES')]))])),
#                                      ('5U',
#                                       OrderedDict([('7603', '5U'),
#                                                    ('template',
#                                                     OrderedDict([('3229 '
#                                                                   'DESKTOP '
#                                                                   'COMPUTER '
#                                                                   'HARDWARE',
#                                                                   'COMPUTER '
#                                                                   'CASES')]))])),
#                                      ('6U',
#                                       OrderedDict([('7604', '6U'),
#                                                    ('template',
# ...
#                               ('BUNDLE MB CPU AMD',
#                                OrderedDict([('template',
#                                              OrderedDict([('motherboards',
#                                                            'BUNDLE MB CPU')])),
#                                             ('9254', 'BUNDLE MB CPU AMD')])),
#                               ('INTEL',
#                                OrderedDict([('template',
#                                              OrderedDict([('desktop_hardware',
#                                                            'MOTHERBOARDS')])),
#                                             ('3547',
#                                              'Intel motherboards by '
#                                              'chipset')])),
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ,
#                          ('PC MONITORS 17',
#                           OrderedDict([('10167', 'MONITORS 17'),
#                                        ('template',
#                                         OrderedDict([('philips',
#                                                       'PC MONITORS')])),
#                                        ('10130', 'MONITORS 17')])),
#                          ('PC MONITORS 21 - 22',
#                           OrderedDict([('10168', 'MONITORS 21 - 22'),
#                                        ('template',
#                                         OrderedDict([('philips',
#                                                       'PC MONITORS')])),
#                                        ('10132', 'MONITORS 21 - 22')])),
#                          ('PC MONITORS 23 - 24',
#                           OrderedDict([('10169', 'MONITORS 23 - 24'),
#                                        ('template',
#                                         OrderedDict([('philips',
#                                                       'PC MONITORS')])),
#                                        ('10133', 'MONITORS 23 - 24')])),
#                          ('PC MONITORS 26 - 28',
#                           OrderedDict([('10170', 'MONITORS 26 - 28'),
#                                        ('template',
#                                         OrderedDict([('philips',
#                                                       'PC MONITORS')])),
#                                        ('10133', 'MONITORS 26 - 28')])),
#                          ('PC MONITORS 29 - 31',
#                           OrderedDict([('10171', 'MONITORS 29 - 31'),
#                                        ('template',
#                                         OrderedDict([('philips',
#                                                       'PC MONITORS')])),
#                                        ('10134', 'MONITORS 29 - 31')])),
#                          ('PC MONITORS 32 - 34',
#                           OrderedDict([('10172', 'MONITORS 32 - 34'),
#                                        ('template',
#                                         OrderedDict([('philips',
#                                                       'PC MONITORS')])),
#                                        ('10135', 'MONITORS 32 - 34')])),
#                          ('PC MONITORS 36 - 40',
#                           OrderedDict([('10173', 'MONITORS 36 - 40'),
#                                        ('template',
#                                         OrderedDict([('philips',
#                                                       'PC MONITORS')])),
#                                        ('10136', 'MONITORS 36 - 40')])),
#                          ('PC MONITORS 40 - 42',
#                           OrderedDict([('10174', 'MONITORS 40 - 42'),
#                                        ('template',
#                                         OrderedDict([('philips',
#                                                       'PC MONITORS')])),
#                                        ('10137', 'MONITORS 40 - 42')])),
#                          ('PC MONITORS 44 - 46',
#                           OrderedDict([('10175', 'MONITORS 44 - 46'),
#                                        ('template',
#                                         OrderedDict([('philips',
#                                                       'PC MONITORS')])),
#                                        ('10138', 'MONITORS 44 - 46')])),
#                          ('PC MONITORS 48 - 50',
#                           OrderedDict([('10176', 'MONITORS 48 - 50'),
#                                        ('template',
#                                         OrderedDict([('philips',
#                                                       'PC MONITORS')])),
#                                        ('10139', 'MONITORS 48 - 50')])),
#                          ('PC MONITORS 52 - 54',
#                           OrderedDict([('10177', 'MONITORS 52 - 54'),
#                                        ('template',
#                                         OrderedDict([('philips',
#                                                       'PC MONITORS')])),
#                                        ('10140', 'MONITORS 52 - 54')]))]),
#  'poco': OrderedDict([('SMATRPHONES',
#                        OrderedDict([('4771', 'POCO'),
#                                     ('template',
#                                      OrderedDict([('consumer electronics root',
#                                                    'SMARTPHONES')])),
#                                     ('4753', 'POCO'),
#                                     ('4754', 'Smartphones')])),
#                       ('HEADPHONES BUDS',
#                        OrderedDict([('7667', 'POCO'),
#                                     ('7666', 'POCO'),
#                                     ('template',
#                                      OrderedDict([('headphones',
#                                                    'BT In-ear Bud')])),
#                                     ('4753', 'POCO'),
#                                     ('7529', 'Headphones')])),
#                       ('POCO C SERIES',
#                        OrderedDict([('6204', 'C Series'),
#                                     ('template',
#                                      OrderedDict([('poco', 'SMATRPHONES')])),
#                                     ('7284', 'C Series')])),
#                       ('POCO M SERIES',
#                        OrderedDict([('6203', 'M Series'),
#                                     ('template',
#                                      OrderedDict([('poco', 'SMATRPHONES')])),
#                                     ('7283', 'M Series')])),
#                       ('POCO F SERIES',
#                        OrderedDict([('6202', 'F Series'),
#                                     ('template',
#                                      OrderedDict([('poco', 'SMATRPHONES')])),
#                                     ('7282', 'F Series')])),
#                       ('POCO X SERIES',
#                        OrderedDict([('6205', 'X Series'),
#                                     ('template',
#                                      OrderedDict([('poco', 'SMATRPHONES')])),
#                                     ('7285', 'X Series')])),
#                       ('POCO C40',
#                        OrderedDict([('7280', 'POCO C40'),
#                                     ('template',
#                                      OrderedDict([('poco', 'POCO C SERIES')])),
#                                     ('4766', 'POCO C40')])),
#                       ('POCO F3',
#                        OrderedDict([('7706', 'POCO F3'),
#                                     ('template',
#                                      OrderedDict([('poco', 'POCO F SERIES')])),
#                                     ('7704', 'POCO F3')])),
#                       ('POCO F3 5G',
#                        OrderedDict([('6207', 'POCO F3 5G'),
#                                     ('template',
#                                      OrderedDict([('poco', 'POCO F3')])),
#                                     ('4758', 'POCO F3 5G')])),
#                       ('POCO F4',
#                        OrderedDict([('7707', 'POCO F4'),
#                                     ('template',
#                                      OrderedDict([('poco', 'POCO F SERIES')])),
#                                     ('7705', 'POCO F4')])),
#                       ('POCO F4 5G',
#                        OrderedDict([('7291', 'POCO F4 5G'),
#                                     ('template',
#                                      OrderedDict([('poco', 'POCO F4')])),
#                                     ('7286', 'POCO F4 5G')])),
#                       ('POCO F4 GT',
#                        OrderedDict([('6206', 'POCO F4 GT'),
#                                     ('template',
#                                      OrderedDict([('poco', 'POCO F4')])),
#                                     ('4755', 'POCO F4 GT')])),
#                       ('POCO M3',
#                        OrderedDict([('6212', 'POCO M3'),
#                                     ('template',
#                                      OrderedDict([('poco', 'POCO M SERIES')])),
#                                     ('4763', 'POCO M3')])),
#                       ('POCO M3 Pro 5G',
#                        OrderedDict([('6210', 'POCO M3 Pro 5G'),
#                                     ('template',
#                                      OrderedDict([('poco', 'POCO M3')])),
#                                     ('4759', 'POCO M3 Pro 5G')])),
#                       ('POCO M3 5G',
#                        OrderedDict([('6210', 'POCO M3 5G'),
#                                     ('template',
#                                      OrderedDict([('poco', 'POCO M3')])),
#                                     ('4759', 'POCO M3 5G')])),
#                       ('POCO M4',
#                        OrderedDict([('7703', 'POCO M4'),
#                                     ('template',
#                                      OrderedDict([('poco', 'POCO M SERIES')])),
#                                     ('7702', 'POCO M4')])),
#                       ('POCO M4 Pro 4G',
#                        OrderedDict([('6209', 'POCO M4 Pro 4G'),
#                                     ('template',
#                                      OrderedDict([('poco', 'POCO M4')])),
#                                     ('4757', 'POCO M4 Pro 4G')])),
#                       ('POCO M4 Pro 5G',
#                        OrderedDict([('6211', 'POCO M4 Pro 5G'),
#                                     ('template',
#                                      OrderedDict([('poco', 'POCO M4')])),
#                                     ('4760', 'POCO M4 Pro 5G')])),
#                       ('POCO M4 5G',
#                        OrderedDict([('7317', 'POCO M4 5G'),
#                                     ('template',
#                                      OrderedDict([('poco', 'POCO M4')])),
#                                     ('7316', 'POCO M4 5G')])),
#                       ('POCO M5',
#                        OrderedDict([('7293', 'POCO M5'),
#                                     ('template',
#                                      OrderedDict([('poco', 'POCO M SERIES')])),
#                                     ('7278', 'POCO M5')])),
#                       ('POCO M5s',
#                        OrderedDict([('7292', 'POCO M5s'),
#                                     ('template',
#                                      OrderedDict([('poco', 'POCO M5')])),
#                                     ('7279', 'POCO M5s')])),
#                       ('POCO X3',
#                        OrderedDict([('7698', 'POCO X3'),
#                                     ('template',
#                                      OrderedDict([('poco', 'POCO X SERIES')])),
#                                     ('7696', 'POCO X3')])),
#                       ('POCO X4',
#                        OrderedDict([('7699', 'POCO X4'),
#                                     ('template',
#                                      OrderedDict([('poco', 'POCO X SERIES')])),
#                                     ('7697', 'POCO X4')])),
#                       ('POCO X3 PRO',
#                        OrderedDict([('7689', 'POCO X3 PRO'),
#                                     ('template',
#                                      OrderedDict([('poco', 'POCO X3')])),
#                                     ('4761', 'POCO X3 PRO')])),
#                       ('POCO X3 GT',
#                        OrderedDict([('7288', 'POCO X3 GT'),
#                                     ('template',
#                                      OrderedDict([('poco', 'POCO X3')])),
#                                     ('4762', 'POCO X3 GT')])),
#                       ('POCO X3 NFC',
#                        OrderedDict([('7289', 'POCO X3 NFC'),
#                                     ('template',
#                                      OrderedDict([('poco', 'POCO X3')])),
#                                     ('4764', 'POCO X3 NFC')])),
#                       ('POCO X4 Pro 5G',
#                        OrderedDict([('7281', 'POCO X4 Pro 5G'),
#                                     ('template',
#                                      OrderedDict([('poco', 'POCO X4')])),
#                                     ('4756', 'POCO X4 Pro 5G')])),
#                       ('POCO X4 GT',
#                        OrderedDict([('6207', 'POCO X4 GT'),
#                                     ('template',
#                                      OrderedDict([('poco', 'POCO X4')])),
#                                     ('4758', 'POCO X4 GT')])),
#                       ('POCO BUDS PRO',
#                        OrderedDict([('7531', 'POCO BUDS PRO'),
#                                     ('template',
#                                      OrderedDict([('poco',
#                                                    'HEADPHONES BUDS')])),
#                                     ('7530', 'POCO BUDS PRO')]))]),
#  'power parts': OrderedDict([('ENERGY', OrderedDict([('3082', 'ENERGY')])),
#                              ('POWER PARTS',
#                               OrderedDict([('7935', 'Power parts'),
#                                            ('template',
#                                             OrderedDict([('power parts',
#                                                           'ENERGY')]))])),
#                              ('BREAKERS',
#                               OrderedDict([('template',
#                                             OrderedDict([('power parts',
#                                                           'POWER PARTS')]))])),
#                              ('AC CONTACTOR',
#                               OrderedDict([('7939', 'AC Contactors'),
#                                            ('template',
#                                             OrderedDict([('power parts',
#                                                           'POWER PARTS')]))])),
#                              ('POWER DRIVER',
#                               OrderedDict([('7938', 'Power Drivers'),
#                                            ('template',
#                                             OrderedDict([('power parts',
#                                                           'POWER PARTS')]))])),
#                              ('MCB BREAKER',
#                               OrderedDict([('7936', 'Air Breaker switch'),
#                                            ('template',
#                                             OrderedDict([('power parts',
#                                                           'BREAKERS')]))])),
#                              ('RC SNUBBER',
#                               OrderedDict([('7937', 'RC Snubber'),
#                                            ('template',
#                                             OrderedDict([('power parts',
#                                                           'ENERGY')]))])),
#                              ('ELECTRIC ENERGY METER',
#                               OrderedDict(

# %%
print(c.get_list_parent_categories(11037))

# %%
list_categories_prestashop = c.get_list_parent_categories_prestashop(11036)

# %%
categories_from_template_files: dict = c.get_list_categories_from_template_files()

# %%
jprint(categories)

# %%
# перечитываю глобальные установки. 
# обычно удобно после измения json
#gs._settings()

# %%
from dict_scenarios import scenario

for key in categories_from_template.keys():
    print(key)

# %%
jprint(categories_from_template['11206 ART DEKO'])

# %%
jprint(categories_from_template['11036 SPACE HOME AND INTERIOR'])

# %%
categories = get_list_categories_from_scenario_category('11209 MURANO GLASS',categories_from_template)

# %%
print(categories)
