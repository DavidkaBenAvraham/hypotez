# %%
import os

# Current working directory
cwd = os.getcwd()
print(cwd)
# Out:
# C:\Users\user2.DESKTOP-CCSNGGD\Documents\repos\stam

# %%
import sys
sys.path.append(cwd)
print(sys.path)
# Out:
# ['C:\\Users\\user2.DESKTOP-CCSNGGD\\Documents\\repos\\stam', 'C:\\Users\\user2.DESKTOP-CCSNGGD\\anaconda3\\python311.zip', 'C:\\Users\\user2.DESKTOP-CCSNGGD\\anaconda3\\DLLs', 'C:\\Users\\user2.DESKTOP-CCSNGGD\\anaconda3\\Lib', 'C:\\Users\\user2.DESKTOP-CCSNGGD\\anaconda3', '', 'C:\\Users\\user2.DESKTOP-CCSNGGD\\anaconda3\\Lib\\site-packages', 'C:\\Users\\user2.DESKTOP-CCSNGGD\\anaconda3\\Lib\\site-packages\\win32', 'C:\\Users\\user2.DESKTOP-CCSNGGD\\anaconda3\\Lib\\site-packages\\win32\\lib', 'C:\\Users\\user2.DESKTOP-CCSNGGD\\anaconda3\\Lib\\site-packages\\Pythonwin', 'C:\\Users\\user2.DESKTOP-CCSNGGD\\Documents\\repos\\stam']
