# %%
from main import run

# %%
run()
# Out:
# worksheet מחשבים וסלולר already exist !
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 run()
#
# File ~\Documents\repos\hypotez-ksp-goog\src\main.py:41, in run()
#      37 for url, category_title in subs.items():
#      39     d.get(url)
# ---> 41     ws.append_row (ws.category (category_title ) )
#      42     brands = ksp.get_all_brands_list()
#      43     print(f'\t\t\t BRANDS:')
#
# File ~\Documents\repos\hypotez-ksp-goog\src\goog\gworksheets.py:58, in GWorksheet.category(self, ws_category_title)
#      57 def category(self, ws_category_title):
# ---> 58     self.render.write_category_title(self, ws_category_title)
#
# File ~\Documents\repos\hypotez-ksp-goog\src\goog\grender.py:115, in GSRender.write_category_title(self, ws, ws_category_title, row)
#     113 table_range: str = f'B{ row }'
# ...
