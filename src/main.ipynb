# %%
import os
import sys
import datetime
from pathlib import Path


dir_root : Path = Path (os.getcwd()[:os.getcwd().rfind('hypotez')+7])
sys.path.append (str (dir_root) )  # Добавляю корневую директорию в sys.path
dir_src = Path (dir_root, 'src') 
sys.path.append (str (dir_root) ) # Добавляю рабочую директорию в sys.path 

from helpers import logger, logs_and_errors_decorator, logger_decorators
logger_decorators.onoff_decorator = False
#from main import launcher

# %%
from src.suppliers.supplier import Supplier
# Out:
# Master password for keepass database: ········
# OK

# %%
s = Supplier('aliexpress','en')
# Out:
# 2023-12-15 18:32:25,273 - INFO -
#                     -----------------------------------
#                             aliexpress
#                     -----------------------------------
#
# 2023-12-15 18:32:25,273 - INFO -
#                     -----------------------------------
#                             aliexpress
#                     -----------------------------------
#
# 2023-12-15 18:32:25,533 - INFO - aliexpress begin to attach driver ...
#                     Старт драйвера  ...
#
# 2023-12-15 18:32:25,533 - INFO - aliexpress begin to attach driver ...
#                     Старт драйвера  ...
#
# 2023-12-15 18:32:25,543 - INFO -
#         ----------------------
#         Старт вебдрайвера firefox.
#         Будет выбран драйвер, подключатся настройки и профиль.
#         На моем компьютере это занимает около полуминуты
#         Ждем....
#         ----------------------
#
#
# 2023-12-15 18:32:25,543 - INFO -
#         ----------------------
#         Старт вебдрайвера firefox.
#         Будет выбран драйвер, подключатся настройки и профиль.
#         На моем компьютере это занимает около полуминуты
#         Ждем....
#         ----------------------
#
#
# 2023-12-15 18:32:25,543 - INFO -  Firefox ...
#
# 2023-12-15 18:32:25,543 - INFO -  Firefox ...
#
# 2023-12-15 18:32:38,740 - INFO -  ... стартовал
#
# 2023-12-15 18:32:38,740 - INFO -  ... стартовал
#
# 2023-12-15 18:32:38,740 - INFO -  ... драйвер подключился за 13 seconds
#
# 2023-12-15 18:32:38,740 - INFO -  ... драйвер подключился за 13 seconds

# %%
d = s.driver

# %%
d.get_url('https://aliexpress.com')
# Out:
# 2023-12-15 18:35:03,436 - ERROR - NoneType: None
#
# 2023-12-15 18:35:03,436 - ERROR - NoneType: None
# False
